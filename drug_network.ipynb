# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

from itertools import combinations
from networkx.drawing.nx_pydot import graphviz_layout

# %%
drug_df = pd.read_excel('./doc_drug_list_0716.xlsx', sheet_name='Sheet1')

# %%
drug_df.fillna('', inplace=True)

# %%
drug_df.head()
# Out:
#           paper_1    paper_2      paper_3       paper_4          paper_5  \
# 0       adenosine   cysteine  chloroquine    atazanavir  andrographolide
# 1         arbidol  lopinavir  favipiravir  azithromycin          arbidol
# 2     baricitinib  ponatinib   remdesivir   chloroquine     azithromycin
# 3     chloroquine  ritonavir    ribavirin      cysteine       bromhexine
# 4  chlorpromazine              sofosbuvir     efavirenz      chloroquine
#
#               paper_6         paper_7       paper_8     paper_9      paper_10  \
# 0             arbidol      amiodarone    atazanavir     alanine    amiodarone
# 1           darunavir     chloroquine   chloroquine  creatinine   amodiaquine
# 2         favipiravir  chlorpromazine  dipyridamole  danoprevir       arbidol
# 3           lopinavir    clomipramine    disulfiram   lopinavir  azithromycin
# 4  methylprednisolone         emetine     indinavir   potassium   chloroquine
#
#       ...          paper_25     paper_26            paper_27     paper_28  \
# 0     ...           arbidol    alvocidib         chloroquine   ampicillin
# 1     ...       baricitinib  amodiaquine  hydroxychloroquine     carmofur
# 2     ...          camostat  baricitinib                      chloroquine
# 3     ...       chloroquine   bortezomib                         cysteine
# 4     ...          cysteine  chloroquine                       disulfiram
#
#       paper_29     paper_30 paper_31     paper_32            paper_33  \
# 0     arginine  chloroquine  heparin    adenosine          amiodarone
# 1     cysteine    lopinavir               arbidol        azithromycin
# 2   disulfiram   remdesivir           chloroquine         chloroquine
# 3  glutathione    ribavirin            disulfiram  hydroxychloroquine
# 4       phenol    ritonavir           favipiravir           potassium
#
#       paper_34
# 0     arginine
# 1  chloroquine
# 2     cysteine
# 3  doxorubicin
# 4  glutathione
#
# [5 rows x 34 columns]

# %%
drug_per_doc = []
for x in drug_df.columns:
#     if x
    mentioned_drug = [x for x in drug_df[x].values if x!='']
#     print(mentioned_drug)
    drug_per_doc.append(mentioned_drug)

# %%
drug_per_doc
# Out:
# [['adenosine',
#   'arbidol',
#   'baricitinib',
#   'chloroquine',
#   'chlorpromazine',
#   'curcumin',
#   'imatinib',
#   'indomethacin',
#   'oseltamivir',
#   'remdesivir',
#   'zanamivir'],
#  ['cysteine', 'lopinavir', 'ponatinib', 'ritonavir'],
#  ['chloroquine', 'favipiravir', 'remdesivir', 'ribavirin', 'sofosbuvir'],
#  ['atazanavir',
#   'azithromycin',
#   'chloroquine',
#   'cysteine',
#   'efavirenz',
#   'hydroxychloroquine',
#   'indinavir',
#   'lopinavir',
#   'nicotinamide',
#   'penicillin',
#   'remdesivir',
#   'ritonavir',
#   'sofosbuvir'],
#  ['andrographolide',
#   'arbidol',
#   'azithromycin',
#   'bromhexine',
#   'chloroquine',
#   'cobicistat',
#   'danoprevir',
#   'darunavir',
#   'dexamethasone',
#   'favipiravir',
#   'fingolimod',
#   'hydrocortisone',
#   'hydroxychloroquine',
#   'lopinavir',
#   'methylprednisolone',
#   'oseltamivir',
#   'pirfenidone',
#   'remdesivir',
#   'ribavirin',
#   'ritonavir',
#   'thalidomide'],
#  ['arbidol',
#   'darunavir',
#   'favipiravir',
#   'lopinavir',
#   'methylprednisolone',
#   'ritonavir'],
#  ['amiodarone',
#   'chloroquine',
#   'chlorpromazine',
#   'clomipramine',
#   'emetine',
#   'fluspirilene',
#   'hydroxychloroquine',
#   'imatinib',
#   'mefloquine',
#   'promethazine',
#   'tamoxifen',
#   'terconazole',
#   'toremifene',
#   'triparanol'],
#  ['atazanavir',
#   'chloroquine',
#   'dipyridamole',
#   'disulfiram',
#   'indinavir',
#   'montelukast',
#   'remdesivir'],
#  ['alanine',
#   'creatinine',
#   'danoprevir',
#   'lopinavir',
#   'potassium',
#   'remdesivir',
#   'ribavirin',
#   'ritonavir',
#   'urea'],
#  ['amiodarone',
#   'amodiaquine',
#   'arbidol',
#   'azithromycin',
#   'chloroquine',
#   'hydroxychloroquine',
#   'nafamostat',
#   'oseltamivir',
#   'remdesivir',
#   'tamoxifen',
#   'toremifene'],
#  ['amodiaquine',
#   'atazanavir',
#   'camostat',
#   'cepharanthine',
#   'chloroquine',
#   'ciclesonide',
#   'digoxin',
#   'favipiravir',
#   'gilteritinib',
#   'hexachlorophene',
#   'hexachlorophene',
#   'ivacaftor',
#   'loperamide',
#   'lopinavir',
#   'mefloquine',
#   'niclosamide',
#   'osimertinib',
#   'proscillaridin',
#   'remdesivir',
#   'tetrandrine',
#   'triparanol'],
#  ['acetylcholine',
#   'alprostadil',
#   'ambroxol',
#   'arbidol',
#   'azithromycin',
#   'chloroquine',
#   'cisatracurium',
#   'darunavir',
#   'dolutegravir',
#   'dopamine',
#   'epinephrine',
#   'erythromycin',
#   'estradiol',
#   'glutathione',
#   'hydroxychloroquine',
#   'ibudilast',
#   'ifenprodil',
#   'isotretinoin',
#   'levofloxacin',
#   'naltrexone',
#   'omeprazole',
#   'remdesivir',
#   'tamoxifen',
#   'thiamine',
#   'vonoprazan'],
#  ['alanine',
#   'arbidol',
#   'chloroquine',
#   'creatine',
#   'creatinine',
#   'ibuprofen',
#   'remdesivir',
#   'sarilumab',
#   'urea'],
#  ['adenosine',
#   'camostat',
#   'cysteine',
#   'glycine',
#   'proline',
#   'remdesivir',
#   'ribavirin'],
#  ['baicalin', 'n3', 'quercetin'],
#  ['adenosine',
#   'arbidol',
#   'baicalin',
#   'camostat',
#   'chloroquine',
#   'doxycycline',
#   'favipiravir',
#   'hesperidin',
#   'lopinavir',
#   'nelfinavir',
#   'oseltamivir',
#   'quinine',
#   'remdesivir',
#   'ribavirin',
#   'ritonavir',
#   'zanamivir'],
#  ['aldosterone',
#   'chloroquine',
#   'dactinomycin',
#   'emodin',
#   'emodin',
#   'melatonin',
#   'mercaptopurine',
#   'mesalazine',
#   'paroxetine',
#   'remdesivir',
#   'sirolimus',
#   'tamoxifen',
#   'toremifene'],
#  ['chloroquine',
#   'chlorpromazine',
#   'doxycycline',
#   'hydroxychloroquine',
#   'quinine',
#   'remdesivir',
#   'ribavirin',
#   'tyrosine'],
#  ['amantadine',
#   'amprenavir',
#   'apixaban',
#   'argatroban',
#   'atazanavir',
#   'atorvastatin',
#   'benzodiazepine',
#   'boceprevir',
#   'bortezomib',
#   'captopril',
#   'clofazimine',
#   'dapsone',
#   'darunavir',
#   'dasatinib',
#   'indinavir',
#   'lisinopril',
#   'lopinavir',
#   'nelfinavir',
#   'penicillin',
#   'ponatinib',
#   'rifampicin',
#   'ritonavir',
#   'rivaroxaban',
#   'saquinavir',
#   'simeprevir',
#   'sorafenib',
#   'telaprevir',
#   'tyrosine'],
#  ['acyclovir',
#   'atazanavir',
#   'boceprevir',
#   'cobicistat',
#   'danoprevir',
#   'darunavir',
#   'dolutegravir',
#   'efavirenz',
#   'indinavir',
#   'lopinavir',
#   'nelfinavir',
#   'raltegravir',
#   'ritonavir',
#   'saquinavir',
#   'simeprevir',
#   'telaprevir'],
#  ['arginine',
#   'etoposide',
#   'hesperidin',
#   'lopinavir',
#   'methylprednisolone',
#   'nelfinavir',
#   'remdesivir',
#   'ribavirin',
#   'ritonavir',
#   'sofosbuvir',
#   'venetoclax'],
#  ['cysteine', 'n3', 'remdesivir'],
#  ['cepharanthine', 'chloroquine', 'mefloquine', 'remdesivir'],
#  ['amprenavir',
#   'atazanavir',
#   'darunavir',
#   'indinavir',
#   'lopinavir',
#   'ritonavir',
#   'saquinavir'],
#  ['arbidol',
#   'baricitinib',
#   'camostat',
#   'chloroquine',
#   'cysteine',
#   'darunavir',
#   'favipiravir',
#   'galidesivir',
#   'hydroxychloroquine',
#   'lopinavir',
#   'nitazoxanide',
#   'remdesivir',
#   'ribavirin',
#   'ritonavir'],
#  ['alvocidib',
#   'amodiaquine',
#   'baricitinib',
#   'bortezomib',
#   'chloroquine',
#   'chlorpromazine',
#   'clomipramine',
#   'dasatinib',
#   'disulfiram',
#   'emetine',
#   'fluspirilene',
#   'fluvastatin',
#   'gilteritinib',
#   'imatinib',
#   'ivermectin',
#   'loperamide',
#   'lopinavir',
#   'mefloquine',
#   'methotrexate',
#   'niclosamide',
#   'nitazoxanide',
#   'penicillin',
#   'promethazine',
#   'remdesivir',
#   'ribavirin',
#   'ritonavir',
#   'sirolimus',
#   'tamoxifen',
#   'terconazole',
#   'toremifene',
#   'tyloxapol',
#   'tyrosine'],
#  ['chloroquine', 'hydroxychloroquine'],
#  ['ampicillin',
#   'carmofur',
#   'chloroquine',
#   'cysteine',
#   'disulfiram',
#   'ebselen',
#   'glutathione',
#   'methionine',
#   'n3',
#   'remdesivir',
#   'urea'],
#  ['arginine',
#   'cysteine',
#   'disulfiram',
#   'glutathione',
#   'phenol',
#   'tryptophan',
#   'tyrosine'],
#  ['chloroquine', 'lopinavir', 'remdesivir', 'ribavirin', 'ritonavir'],
#  ['heparin'],
#  ['adenosine',
#   'arbidol',
#   'chloroquine',
#   'disulfiram',
#   'favipiravir',
#   'galidesivir',
#   'lopinavir',
#   'nitazoxanide',
#   'oseltamivir',
#   'remdesivir',
#   'ribavirin',
#   'ritonavir',
#   'tenofovir'],
#  ['amiodarone',
#   'azithromycin',
#   'chloroquine',
#   'hydroxychloroquine',
#   'potassium',
#   'remdesivir'],
#  ['arginine',
#   'chloroquine',
#   'cysteine',
#   'doxorubicin',
#   'glutathione',
#   'metformin',
#   'penicillin',
#   'phenol',
#   'remdesivir']]

# %%
all_drugs = []
for x in drug_per_doc:
    all_drugs.extend(x)

# %%
z = dict.fromkeys(all_drugs,0)
for x in all_drugs:
    z[x]+=1

# %%
import operator
sorted_z = sorted(z.items(), key=operator.itemgetter(1), reverse=True)
sorted_z
# Out:
# [('remdesivir', 24),
#  ('chloroquine', 22),
#  ('lopinavir', 15),
#  ('ritonavir', 14),
#  ('ribavirin', 11),
#  ('arbidol', 9),
#  ('hydroxychloroquine', 9),
#  ('cysteine', 8),
#  ('favipiravir', 7),
#  ('darunavir', 7),
#  ('atazanavir', 6),
#  ('oseltamivir', 5),
#  ('azithromycin', 5),
#  ('indinavir', 5),
#  ('tamoxifen', 5),
#  ('disulfiram', 5),
#  ('adenosine', 4),
#  ('chlorpromazine', 4),
#  ('penicillin', 4),
#  ('mefloquine', 4),
#  ('toremifene', 4),
#  ('camostat', 4),
#  ('glutathione', 4),
#  ('nelfinavir', 4),
#  ('tyrosine', 4),
#  ('baricitinib', 3),
#  ('imatinib', 3),
#  ('sofosbuvir', 3),
#  ('danoprevir', 3),
#  ('methylprednisolone', 3),
#  ('amiodarone', 3),
#  ('urea', 3),
#  ('amodiaquine', 3),
#  ('n3', 3),
#  ('saquinavir', 3),
#  ('arginine', 3),
#  ('nitazoxanide', 3),
#  ('zanamivir', 2),
#  ('ponatinib', 2),
#  ('efavirenz', 2),
#  ('cobicistat', 2),
#  ('clomipramine', 2),
#  ('emetine', 2),
#  ('fluspirilene', 2),
#  ('promethazine', 2),
#  ('terconazole', 2),
#  ('triparanol', 2),
#  ('alanine', 2),
#  ('creatinine', 2),
#  ('potassium', 2),
#  ('cepharanthine', 2),
#  ('gilteritinib', 2),
#  ('hexachlorophene', 2),
#  ('loperamide', 2),
#  ('niclosamide', 2),
#  ('dolutegravir', 2),
#  ('baicalin', 2),
#  ('doxycycline', 2),
#  ('hesperidin', 2),
#  ('quinine', 2),
#  ('emodin', 2),
#  ('sirolimus', 2),
#  ('amprenavir', 2),
#  ('boceprevir', 2),
#  ('bortezomib', 2),
#  ('dasatinib', 2),
#  ('simeprevir', 2),
#  ('telaprevir', 2),
#  ('galidesivir', 2),
#  ('phenol', 2),
#  ('curcumin', 1),
#  ('indomethacin', 1),
#  ('nicotinamide', 1),
#  ('andrographolide', 1),
#  ('bromhexine', 1),
#  ('dexamethasone', 1),
#  ('fingolimod', 1),
#  ('hydrocortisone', 1),
#  ('pirfenidone', 1),
#  ('thalidomide', 1),
#  ('dipyridamole', 1),
#  ('montelukast', 1),
#  ('nafamostat', 1),
#  ('ciclesonide', 1),
#  ('digoxin', 1),
#  ('ivacaftor', 1),
#  ('osimertinib', 1),
#  ('proscillaridin', 1),
#  ('tetrandrine', 1),
#  ('acetylcholine', 1),
#  ('alprostadil', 1),
#  ('ambroxol', 1),
#  ('cisatracurium', 1),
#  ('dopamine', 1),
#  ('epinephrine', 1),
#  ('erythromycin', 1),
#  ('estradiol', 1),
#  ('ibudilast', 1),
#  ('ifenprodil', 1),
#  ('isotretinoin', 1),
#  ('levofloxacin', 1),
#  ('naltrexone', 1),
#  ('omeprazole', 1),
#  ('thiamine', 1),
#  ('vonoprazan', 1),
#  ('creatine', 1),
#  ('ibuprofen', 1),
#  ('sarilumab', 1),
#  ('glycine', 1),
#  ('proline', 1),
#  ('quercetin', 1),
#  ('aldosterone', 1),
#  ('dactinomycin', 1),
#  ('melatonin', 1),
#  ('mercaptopurine', 1),
#  ('mesalazine', 1),
#  ('paroxetine', 1),
#  ('amantadine', 1),
#  ('apixaban', 1),
#  ('argatroban', 1),
#  ('atorvastatin', 1),
#  ('benzodiazepine', 1),
#  ('captopril', 1),
#  ('clofazimine', 1),
#  ('dapsone', 1),
#  ('lisinopril', 1),
#  ('rifampicin', 1),
#  ('rivaroxaban', 1),
#  ('sorafenib', 1),
#  ('acyclovir', 1),
#  ('raltegravir', 1),
#  ('etoposide', 1),
#  ('venetoclax', 1),
#  ('alvocidib', 1),
#  ('fluvastatin', 1),
#  ('ivermectin', 1),
#  ('methotrexate', 1),
#  ('tyloxapol', 1),
#  ('ampicillin', 1),
#  ('carmofur', 1),
#  ('ebselen', 1),
#  ('methionine', 1),
#  ('tryptophan', 1),
#  ('heparin', 1),
#  ('tenofovir', 1),
#  ('doxorubicin', 1),
#  ('metformin', 1)]

# %%
all_drugs = []
for x in drug_per_doc:
    all_drugs.extend(x)
all_drugs = list(set(all_drugs))

# %%
len(all_drugs)
# Out:
# 147

# %%
all_drugs
# Out:
# ['triparanol',
#  'toremifene',
#  'ciclesonide',
#  'thalidomide',
#  'chloroquine',
#  'proline',
#  'sorafenib',
#  'mesalazine',
#  'zanamivir',
#  'hydroxychloroquine',
#  'captopril',
#  'nelfinavir',
#  'amodiaquine',
#  'erythromycin',
#  'amiodarone',
#  'hesperidin',
#  'ponatinib',
#  'saquinavir',
#  'disulfiram',
#  'atazanavir',
#  'ibuprofen',
#  'montelukast',
#  'lopinavir',
#  'indinavir',
#  'tyrosine',
#  'methionine',
#  'thiamine',
#  'clofazimine',
#  'dasatinib',
#  'loperamide',
#  'hexachlorophene',
#  'ambroxol',
#  'melatonin',
#  'quercetin',
#  'urea',
#  'fingolimod',
#  'quinine',
#  'favipiravir',
#  'creatinine',
#  'emodin',
#  'amantadine',
#  'bromhexine',
#  'sirolimus',
#  'simeprevir',
#  'remdesivir',
#  'nitazoxanide',
#  'hydrocortisone',
#  'mefloquine',
#  'bortezomib',
#  'phenol',
#  'potassium',
#  'benzodiazepine',
#  'ivacaftor',
#  'darunavir',
#  'vonoprazan',
#  'tenofovir',
#  'gilteritinib',
#  'ifenprodil',
#  'omeprazole',
#  'heparin',
#  'camostat',
#  'estradiol',
#  'methylprednisolone',
#  'emetine',
#  'ibudilast',
#  'carmofur',
#  'apixaban',
#  'argatroban',
#  'baicalin',
#  'rifampicin',
#  'ampicillin',
#  'telaprevir',
#  'andrographolide',
#  'fluspirilene',
#  'tryptophan',
#  'dipyridamole',
#  'dolutegravir',
#  'promethazine',
#  'nafamostat',
#  'alvocidib',
#  'lisinopril',
#  'dopamine',
#  'dactinomycin',
#  'efavirenz',
#  'cepharanthine',
#  'n3',
#  'nicotinamide',
#  'levofloxacin',
#  'alanine',
#  'sofosbuvir',
#  'arbidol',
#  'tyloxapol',
#  'etoposide',
#  'creatine',
#  'naltrexone',
#  'proscillaridin',
#  'azithromycin',
#  'indomethacin',
#  'penicillin',
#  'acetylcholine',
#  'glutathione',
#  'mercaptopurine',
#  'digoxin',
#  'cysteine',
#  'dapsone',
#  'boceprevir',
#  'ivermectin',
#  'osimertinib',
#  'alprostadil',
#  'atorvastatin',
#  'ebselen',
#  'pirfenidone',
#  'venetoclax',
#  'galidesivir',
#  'fluvastatin',
#  'isotretinoin',
#  'amprenavir',
#  'methotrexate',
#  'tetrandrine',
#  'arginine',
#  'terconazole',
#  'imatinib',
#  'baricitinib',
#  'clomipramine',
#  'doxycycline',
#  'dexamethasone',
#  'chlorpromazine',
#  'doxorubicin',
#  'metformin',
#  'rivaroxaban',
#  'cobicistat',
#  'acyclovir',
#  'tamoxifen',
#  'curcumin',
#  'niclosamide',
#  'oseltamivir',
#  'paroxetine',
#  'epinephrine',
#  'danoprevir',
#  'cisatracurium',
#  'raltegravir',
#  'adenosine',
#  'ribavirin',
#  'aldosterone',
#  'glycine',
#  'sarilumab',
#  'ritonavir']

# %%
connected_dic = {}
for drug in all_drugs:
    drug_contain_idx =[]
    for idx in range(len(drug_per_doc)):
        if drug in drug_per_doc[idx]:
            drug_contain_idx.append(idx+1)
    print(drug_contain_idx)
    if len(drug_contain_idx)==1:
        connected_dic[drug] = [(drug_contain_idx[0],drug_contain_idx[0] )]
        continue
    connected_node = list(combinations(drug_contain_idx, 2))
    connected_dic[drug] = connected_node
#     print(connected_node)
# Out:
# [7, 11]
# [7, 10, 17, 26]
# [11]
# [5]
# [1, 3, 4, 5, 7, 8, 10, 11, 12, 13, 16, 17, 18, 23, 25, 26, 27, 28, 30, 32, 33, 34]
# [14]
# [19]
# [17]
# [1, 16]
# [4, 5, 7, 10, 12, 18, 25, 27, 33]
# [19]
# [16, 19, 20, 21]
# [10, 11, 26]
# [12]
# [7, 10, 33]
# [16, 21]
# [2, 19]
# [19, 20, 24]
# [8, 26, 28, 29, 32]
# [4, 8, 11, 19, 20, 24]
# [13]
# [8]
# [2, 4, 5, 6, 9, 11, 16, 19, 20, 21, 24, 25, 26, 30, 32]
# [4, 8, 19, 20, 24]
# [18, 19, 26, 29]
# [28]
# [12]
# [19]
# [19, 26]
# [11, 26]
# [11]
# [12]
# [17]
# [15]
# [9, 13, 28]
# [5]
# [16, 18]
# [3, 5, 6, 11, 16, 25, 32]
# [9, 13]
# [17]
# [19]
# [5]
# [17, 26]
# [19, 20]
# [1, 3, 4, 5, 8, 9, 10, 11, 12, 13, 14, 16, 17, 18, 21, 22, 23, 25, 26, 28, 30, 32, 33, 34]
# [25, 26, 32]
# [5]
# [7, 11, 23, 26]
# [19, 26]
# [29, 34]
# [9, 33]
# [19]
# [11]
# [5, 6, 12, 19, 20, 24, 25]
# [12]
# [32]
# [11, 26]
# [12]
# [12]
# [31]
# [11, 14, 16, 25]
# [12]
# [5, 6, 21]
# [7, 26]
# [12]
# [28]
# [19]
# [19]
# [15, 16]
# [19]
# [28]
# [19, 20]
# [5]
# [7, 26]
# [29]
# [8]
# [12, 20]
# [7, 26]
# [10]
# [26]
# [19]
# [12]
# [17]
# [4, 20]
# [11, 23]
# [15, 22, 28]
# [4]
# [12]
# [9, 13]
# [3, 4, 21]
# [1, 5, 6, 10, 12, 13, 16, 25, 32]
# [26]
# [21]
# [13]
# [12]
# [11]
# [4, 5, 10, 12, 33]
# [1]
# [4, 19, 26, 34]
# [12]
# [12, 28, 29, 34]
# [17]
# [11]
# [2, 4, 14, 22, 25, 28, 29, 34]
# [19]
# [19, 20]
# [26]
# [11]
# [12]
# [19]
# [28]
# [5]
# [21]
# [25, 32]
# [26]
# [12]
# [19, 24]
# [26]
# [11]
# [21, 29, 34]
# [7, 26]
# [1, 7, 26]
# [1, 25, 26]
# [7, 26]
# [16, 18]
# [5]
# [1, 7, 18, 26]
# [34]
# [34]
# [19]
# [5, 20]
# [20]
# [7, 10, 12, 17, 26]
# [1]
# [11, 26]
# [1, 5, 10, 16, 32]
# [17]
# [12]
# [5, 9, 20]
# [12]
# [20]
# [1, 14, 16, 32]
# [3, 5, 9, 14, 16, 18, 21, 25, 26, 30, 32]
# [17]
# [14]
# [13]
# [2, 4, 5, 6, 9, 16, 19, 20, 21, 24, 25, 26, 30, 32]

# %%
connected_dic['heparin']
# Out:
# [(31, 31)]

# %%
for x,y in connected_dic.items():
#     print(y)
    for z in y:
        c =list(z)
        c.append(x)
        print(str(c[0])+'\t'+str(c[1])+'\t'+str(c[2]))
# Out:
# 7	11	triparanol
# 7	10	toremifene
# 7	17	toremifene
# 7	26	toremifene
# 10	17	toremifene
# 10	26	toremifene
# 17	26	toremifene
# 11	11	ciclesonide
# 5	5	thalidomide
# 1	3	chloroquine
# 1	4	chloroquine
# 1	5	chloroquine
# 1	7	chloroquine
# 1	8	chloroquine
# 1	10	chloroquine
# 1	11	chloroquine
# 1	12	chloroquine
# 1	13	chloroquine
# 1	16	chloroquine
# 1	17	chloroquine
# 1	18	chloroquine
# 1	23	chloroquine
# 1	25	chloroquine
# 1	26	chloroquine
# 1	27	chloroquine
# 1	28	chloroquine
# 1	30	chloroquine
# 1	32	chloroquine
# 1	33	chloroquine
# 1	34	chloroquine
# 3	4	chloroquine
# 3	5	chloroquine
# 3	7	chloroquine
# 3	8	chloroquine
# 3	10	chloroquine
# 3	11	chloroquine
# 3	12	chloroquine
# 3	13	chloroquine
# 3	16	chloroquine
# 3	17	chloroquine
# 3	18	chloroquine
# 3	23	chloroquine
# 3	25	chloroquine
# 3	26	chloroquine
# 3	27	chloroquine
# 3	28	chloroquine
# 3	30	chloroquine
# 3	32	chloroquine
# 3	33	chloroquine
# 3	34	chloroquine
# 4	5	chloroquine
# 4	7	chloroquine
# 4	8	chloroquine
# 4	10	chloroquine
# 4	11	chloroquine
# 4	12	chloroquine
# 4	13	chloroquine
# 4	16	chloroquine
# 4	17	chloroquine
# 4	18	chloroquine
# 4	23	chloroquine
# 4	25	chloroquine
# 4	26	chloroquine
# 4	27	chloroquine
# 4	28	chloroquine
# 4	30	chloroquine
# 4	32	chloroquine
# 4	33	chloroquine
# 4	34	chloroquine
# 5	7	chloroquine
# 5	8	chloroquine
# 5	10	chloroquine
# 5	11	chloroquine
# 5	12	chloroquine
# 5	13	chloroquine
# 5	16	chloroquine
# 5	17	chloroquine
# 5	18	chloroquine
# 5	23	chloroquine
# 5	25	chloroquine
# 5	26	chloroquine
# 5	27	chloroquine
# 5	28	chloroquine
# 5	30	chloroquine
# 5	32	chloroquine
# 5	33	chloroquine
# 5	34	chloroquine
# 7	8	chloroquine
# 7	10	chloroquine
# 7	11	chloroquine
# 7	12	chloroquine
# 7	13	chloroquine
# 7	16	chloroquine
# 7	17	chloroquine
# 7	18	chloroquine
# 7	23	chloroquine
# 7	25	chloroquine
# 7	26	chloroquine
# 7	27	chloroquine
# 7	28	chloroquine
# 7	30	chloroquine
# 7	32	chloroquine
# 7	33	chloroquine
# 7	34	chloroquine
# 8	10	chloroquine
# 8	11	chloroquine
# 8	12	chloroquine
# 8	13	chloroquine
# 8	16	chloroquine
# 8	17	chloroquine
# 8	18	chloroquine
# 8	23	chloroquine
# 8	25	chloroquine
# 8	26	chloroquine
# 8	27	chloroquine
# 8	28	chloroquine
# 8	30	chloroquine
# 8	32	chloroquine
# 8	33	chloroquine
# 8	34	chloroquine
# 10	11	chloroquine
# 10	12	chloroquine
# 10	13	chloroquine
# 10	16	chloroquine
# 10	17	chloroquine
# 10	18	chloroquine
# 10	23	chloroquine
# 10	25	chloroquine
# 10	26	chloroquine
# 10	27	chloroquine
# 10	28	chloroquine
# 10	30	chloroquine
# 10	32	chloroquine
# 10	33	chloroquine
# 10	34	chloroquine
# 11	12	chloroquine
# 11	13	chloroquine
# 11	16	chloroquine
# 11	17	chloroquine
# 11	18	chloroquine
# 11	23	chloroquine
# 11	25	chloroquine
# 11	26	chloroquine
# 11	27	chloroquine
# 11	28	chloroquine
# 11	30	chloroquine
# 11	32	chloroquine
# 11	33	chloroquine
# 11	34	chloroquine
# 12	13	chloroquine
# 12	16	chloroquine
# 12	17	chloroquine
# 12	18	chloroquine
# 12	23	chloroquine
# 12	25	chloroquine
# 12	26	chloroquine
# 12	27	chloroquine
# 12	28	chloroquine
# 12	30	chloroquine
# 12	32	chloroquine
# 12	33	chloroquine
# 12	34	chloroquine
# 13	16	chloroquine
# 13	17	chloroquine
# 13	18	chloroquine
# 13	23	chloroquine
# 13	25	chloroquine
# 13	26	chloroquine
# 13	27	chloroquine
# 13	28	chloroquine
# 13	30	chloroquine
# 13	32	chloroquine
# 13	33	chloroquine
# 13	34	chloroquine
# 16	17	chloroquine
# 16	18	chloroquine
# 16	23	chloroquine
# 16	25	chloroquine
# 16	26	chloroquine
# 16	27	chloroquine
# 16	28	chloroquine
# 16	30	chloroquine
# 16	32	chloroquine
# 16	33	chloroquine
# 16	34	chloroquine
# 17	18	chloroquine
# 17	23	chloroquine
# 17	25	chloroquine
# 17	26	chloroquine
# 17	27	chloroquine
# 17	28	chloroquine
# 17	30	chloroquine
# 17	32	chloroquine
# 17	33	chloroquine
# 17	34	chloroquine
# 18	23	chloroquine
# 18	25	chloroquine
# 18	26	chloroquine
# 18	27	chloroquine
# 18	28	chloroquine
# 18	30	chloroquine
# 18	32	chloroquine
# 18	33	chloroquine
# 18	34	chloroquine
# 23	25	chloroquine
# 23	26	chloroquine
# 23	27	chloroquine
# 23	28	chloroquine
# 23	30	chloroquine
# 23	32	chloroquine
# 23	33	chloroquine
# 23	34	chloroquine
# 25	26	chloroquine
# 25	27	chloroquine
# 25	28	chloroquine
# 25	30	chloroquine
# 25	32	chloroquine
# 25	33	chloroquine
# 25	34	chloroquine
# 26	27	chloroquine
# 26	28	chloroquine
# 26	30	chloroquine
# 26	32	chloroquine
# 26	33	chloroquine
# 26	34	chloroquine
# 27	28	chloroquine
# 27	30	chloroquine
# 27	32	chloroquine
# 27	33	chloroquine
# 27	34	chloroquine
# 28	30	chloroquine
# 28	32	chloroquine
# 28	33	chloroquine
# 28	34	chloroquine
# 30	32	chloroquine
# 30	33	chloroquine
# 30	34	chloroquine
# 32	33	chloroquine
# 32	34	chloroquine
# 33	34	chloroquine
# 14	14	proline
# 19	19	sorafenib
# 17	17	mesalazine
# 1	16	zanamivir
# 4	5	hydroxychloroquine
# 4	7	hydroxychloroquine
# 4	10	hydroxychloroquine
# 4	12	hydroxychloroquine
# 4	18	hydroxychloroquine
# 4	25	hydroxychloroquine
# 4	27	hydroxychloroquine
# 4	33	hydroxychloroquine
# 5	7	hydroxychloroquine
# 5	10	hydroxychloroquine
# 5	12	hydroxychloroquine
# 5	18	hydroxychloroquine
# 5	25	hydroxychloroquine
# 5	27	hydroxychloroquine
# 5	33	hydroxychloroquine
# 7	10	hydroxychloroquine
# 7	12	hydroxychloroquine
# 7	18	hydroxychloroquine
# 7	25	hydroxychloroquine
# 7	27	hydroxychloroquine
# 7	33	hydroxychloroquine
# 10	12	hydroxychloroquine
# 10	18	hydroxychloroquine
# 10	25	hydroxychloroquine
# 10	27	hydroxychloroquine
# 10	33	hydroxychloroquine
# 12	18	hydroxychloroquine
# 12	25	hydroxychloroquine
# 12	27	hydroxychloroquine
# 12	33	hydroxychloroquine
# 18	25	hydroxychloroquine
# 18	27	hydroxychloroquine
# 18	33	hydroxychloroquine
# 25	27	hydroxychloroquine
# 25	33	hydroxychloroquine
# 27	33	hydroxychloroquine
# 19	19	captopril
# 16	19	nelfinavir
# 16	20	nelfinavir
# 16	21	nelfinavir
# 19	20	nelfinavir
# 19	21	nelfinavir
# 20	21	nelfinavir
# 10	11	amodiaquine
# 10	26	amodiaquine
# 11	26	amodiaquine
# 12	12	erythromycin
# 7	10	amiodarone
# 7	33	amiodarone
# 10	33	amiodarone
# 16	21	hesperidin
# 2	19	ponatinib
# 19	20	saquinavir
# 19	24	saquinavir
# 20	24	saquinavir
# 8	26	disulfiram
# 8	28	disulfiram
# 8	29	disulfiram
# 8	32	disulfiram
# 26	28	disulfiram
# 26	29	disulfiram
# 26	32	disulfiram
# 28	29	disulfiram
# 28	32	disulfiram
# 29	32	disulfiram
# 4	8	atazanavir
# 4	11	atazanavir
# 4	19	atazanavir
# 4	20	atazanavir
# 4	24	atazanavir
# 8	11	atazanavir
# 8	19	atazanavir
# 8	20	atazanavir
# 8	24	atazanavir
# 11	19	atazanavir
# 11	20	atazanavir
# 11	24	atazanavir
# 19	20	atazanavir
# 19	24	atazanavir
# 20	24	atazanavir
# 13	13	ibuprofen
# 8	8	montelukast
# 2	4	lopinavir
# 2	5	lopinavir
# 2	6	lopinavir
# 2	9	lopinavir
# 2	11	lopinavir
# 2	16	lopinavir
# 2	19	lopinavir
# 2	20	lopinavir
# 2	21	lopinavir
# 2	24	lopinavir
# 2	25	lopinavir
# 2	26	lopinavir
# 2	30	lopinavir
# 2	32	lopinavir
# 4	5	lopinavir
# 4	6	lopinavir
# 4	9	lopinavir
# 4	11	lopinavir
# 4	16	lopinavir
# 4	19	lopinavir
# 4	20	lopinavir
# 4	21	lopinavir
# 4	24	lopinavir
# 4	25	lopinavir
# 4	26	lopinavir
# 4	30	lopinavir
# 4	32	lopinavir
# 5	6	lopinavir
# 5	9	lopinavir
# 5	11	lopinavir
# 5	16	lopinavir
# 5	19	lopinavir
# 5	20	lopinavir
# 5	21	lopinavir
# 5	24	lopinavir
# 5	25	lopinavir
# 5	26	lopinavir
# 5	30	lopinavir
# 5	32	lopinavir
# 6	9	lopinavir
# 6	11	lopinavir
# 6	16	lopinavir
# 6	19	lopinavir
# 6	20	lopinavir
# 6	21	lopinavir
# 6	24	lopinavir
# 6	25	lopinavir
# 6	26	lopinavir
# 6	30	lopinavir
# 6	32	lopinavir
# 9	11	lopinavir
# 9	16	lopinavir
# 9	19	lopinavir
# 9	20	lopinavir
# 9	21	lopinavir
# 9	24	lopinavir
# 9	25	lopinavir
# 9	26	lopinavir
# 9	30	lopinavir
# 9	32	lopinavir
# 11	16	lopinavir
# 11	19	lopinavir
# 11	20	lopinavir
# 11	21	lopinavir
# 11	24	lopinavir
# 11	25	lopinavir
# 11	26	lopinavir
# 11	30	lopinavir
# 11	32	lopinavir
# 16	19	lopinavir
# 16	20	lopinavir
# 16	21	lopinavir
# 16	24	lopinavir
# 16	25	lopinavir
# 16	26	lopinavir
# 16	30	lopinavir
# 16	32	lopinavir
# 19	20	lopinavir
# 19	21	lopinavir
# 19	24	lopinavir
# 19	25	lopinavir
# 19	26	lopinavir
# 19	30	lopinavir
# 19	32	lopinavir
# 20	21	lopinavir
# 20	24	lopinavir
# 20	25	lopinavir
# 20	26	lopinavir
# 20	30	lopinavir
# 20	32	lopinavir
# 21	24	lopinavir
# 21	25	lopinavir
# 21	26	lopinavir
# 21	30	lopinavir
# 21	32	lopinavir
# 24	25	lopinavir
# 24	26	lopinavir
# 24	30	lopinavir
# 24	32	lopinavir
# 25	26	lopinavir
# 25	30	lopinavir
# 25	32	lopinavir
# 26	30	lopinavir
# 26	32	lopinavir
# 30	32	lopinavir
# 4	8	indinavir
# 4	19	indinavir
# 4	20	indinavir
# 4	24	indinavir
# 8	19	indinavir
# 8	20	indinavir
# 8	24	indinavir
# 19	20	indinavir
# 19	24	indinavir
# 20	24	indinavir
# 18	19	tyrosine
# 18	26	tyrosine
# 18	29	tyrosine
# 19	26	tyrosine
# 19	29	tyrosine
# 26	29	tyrosine
# 28	28	methionine
# 12	12	thiamine
# 19	19	clofazimine
# 19	26	dasatinib
# 11	26	loperamide
# 11	11	hexachlorophene
# 12	12	ambroxol
# 17	17	melatonin
# 15	15	quercetin
# 9	13	urea
# 9	28	urea
# 13	28	urea
# 5	5	fingolimod
# 16	18	quinine
# 3	5	favipiravir
# 3	6	favipiravir
# 3	11	favipiravir
# 3	16	favipiravir
# 3	25	favipiravir
# 3	32	favipiravir
# 5	6	favipiravir
# 5	11	favipiravir
# 5	16	favipiravir
# 5	25	favipiravir
# 5	32	favipiravir
# 6	11	favipiravir
# 6	16	favipiravir
# 6	25	favipiravir
# 6	32	favipiravir
# 11	16	favipiravir
# 11	25	favipiravir
# 11	32	favipiravir
# 16	25	favipiravir
# 16	32	favipiravir
# 25	32	favipiravir
# 9	13	creatinine
# 17	17	emodin
# 19	19	amantadine
# 5	5	bromhexine
# 17	26	sirolimus
# 19	20	simeprevir
# 1	3	remdesivir
# 1	4	remdesivir
# 1	5	remdesivir
# 1	8	remdesivir
# 1	9	remdesivir
# 1	10	remdesivir
# 1	11	remdesivir
# 1	12	remdesivir
# 1	13	remdesivir
# 1	14	remdesivir
# 1	16	remdesivir
# 1	17	remdesivir
# 1	18	remdesivir
# 1	21	remdesivir
# 1	22	remdesivir
# 1	23	remdesivir
# 1	25	remdesivir
# 1	26	remdesivir
# 1	28	remdesivir
# 1	30	remdesivir
# 1	32	remdesivir
# 1	33	remdesivir
# 1	34	remdesivir
# 3	4	remdesivir
# 3	5	remdesivir
# 3	8	remdesivir
# 3	9	remdesivir
# 3	10	remdesivir
# 3	11	remdesivir
# 3	12	remdesivir
# 3	13	remdesivir
# 3	14	remdesivir
# 3	16	remdesivir
# 3	17	remdesivir
# 3	18	remdesivir
# 3	21	remdesivir
# 3	22	remdesivir
# 3	23	remdesivir
# 3	25	remdesivir
# 3	26	remdesivir
# 3	28	remdesivir
# 3	30	remdesivir
# 3	32	remdesivir
# 3	33	remdesivir
# 3	34	remdesivir
# 4	5	remdesivir
# 4	8	remdesivir
# 4	9	remdesivir
# 4	10	remdesivir
# 4	11	remdesivir
# 4	12	remdesivir
# 4	13	remdesivir
# 4	14	remdesivir
# 4	16	remdesivir
# 4	17	remdesivir
# 4	18	remdesivir
# 4	21	remdesivir
# 4	22	remdesivir
# 4	23	remdesivir
# 4	25	remdesivir
# 4	26	remdesivir
# 4	28	remdesivir
# 4	30	remdesivir
# 4	32	remdesivir
# 4	33	remdesivir
# 4	34	remdesivir
# 5	8	remdesivir
# 5	9	remdesivir
# 5	10	remdesivir
# 5	11	remdesivir
# 5	12	remdesivir
# 5	13	remdesivir
# 5	14	remdesivir
# 5	16	remdesivir
# 5	17	remdesivir
# 5	18	remdesivir
# 5	21	remdesivir
# 5	22	remdesivir
# 5	23	remdesivir
# 5	25	remdesivir
# 5	26	remdesivir
# 5	28	remdesivir
# 5	30	remdesivir
# 5	32	remdesivir
# 5	33	remdesivir
# 5	34	remdesivir
# 8	9	remdesivir
# 8	10	remdesivir
# 8	11	remdesivir
# 8	12	remdesivir
# 8	13	remdesivir
# 8	14	remdesivir
# 8	16	remdesivir
# 8	17	remdesivir
# 8	18	remdesivir
# 8	21	remdesivir
# 8	22	remdesivir
# 8	23	remdesivir
# 8	25	remdesivir
# 8	26	remdesivir
# 8	28	remdesivir
# 8	30	remdesivir
# 8	32	remdesivir
# 8	33	remdesivir
# 8	34	remdesivir
# 9	10	remdesivir
# 9	11	remdesivir
# 9	12	remdesivir
# 9	13	remdesivir
# 9	14	remdesivir
# 9	16	remdesivir
# 9	17	remdesivir
# 9	18	remdesivir
# 9	21	remdesivir
# 9	22	remdesivir
# 9	23	remdesivir
# 9	25	remdesivir
# 9	26	remdesivir
# 9	28	remdesivir
# 9	30	remdesivir
# 9	32	remdesivir
# 9	33	remdesivir
# 9	34	remdesivir
# 10	11	remdesivir
# 10	12	remdesivir
# 10	13	remdesivir
# 10	14	remdesivir
# 10	16	remdesivir
# 10	17	remdesivir
# 10	18	remdesivir
# 10	21	remdesivir
# 10	22	remdesivir
# 10	23	remdesivir
# 10	25	remdesivir
# 10	26	remdesivir
# 10	28	remdesivir
# 10	30	remdesivir
# 10	32	remdesivir
# 10	33	remdesivir
# 10	34	remdesivir
# 11	12	remdesivir
# 11	13	remdesivir
# 11	14	remdesivir
# 11	16	remdesivir
# 11	17	remdesivir
# 11	18	remdesivir
# 11	21	remdesivir
# 11	22	remdesivir
# 11	23	remdesivir
# 11	25	remdesivir
# 11	26	remdesivir
# 11	28	remdesivir
# 11	30	remdesivir
# 11	32	remdesivir
# 11	33	remdesivir
# 11	34	remdesivir
# 12	13	remdesivir
# 12	14	remdesivir
# 12	16	remdesivir
# 12	17	remdesivir
# 12	18	remdesivir
# 12	21	remdesivir
# 12	22	remdesivir
# 12	23	remdesivir
# 12	25	remdesivir
# 12	26	remdesivir
# 12	28	remdesivir
# 12	30	remdesivir
# 12	32	remdesivir
# 12	33	remdesivir
# 12	34	remdesivir
# 13	14	remdesivir
# 13	16	remdesivir
# 13	17	remdesivir
# 13	18	remdesivir
# 13	21	remdesivir
# 13	22	remdesivir
# 13	23	remdesivir
# 13	25	remdesivir
# 13	26	remdesivir
# 13	28	remdesivir
# 13	30	remdesivir
# 13	32	remdesivir
# 13	33	remdesivir
# 13	34	remdesivir
# 14	16	remdesivir
# 14	17	remdesivir
# 14	18	remdesivir
# 14	21	remdesivir
# 14	22	remdesivir
# 14	23	remdesivir
# 14	25	remdesivir
# 14	26	remdesivir
# 14	28	remdesivir
# 14	30	remdesivir
# 14	32	remdesivir
# 14	33	remdesivir
# 14	34	remdesivir
# 16	17	remdesivir
# 16	18	remdesivir
# 16	21	remdesivir
# 16	22	remdesivir
# 16	23	remdesivir
# 16	25	remdesivir
# 16	26	remdesivir
# 16	28	remdesivir
# 16	30	remdesivir
# 16	32	remdesivir
# 16	33	remdesivir
# 16	34	remdesivir
# 17	18	remdesivir
# 17	21	remdesivir
# 17	22	remdesivir
# 17	23	remdesivir
# 17	25	remdesivir
# 17	26	remdesivir
# 17	28	remdesivir
# 17	30	remdesivir
# 17	32	remdesivir
# 17	33	remdesivir
# 17	34	remdesivir
# 18	21	remdesivir
# 18	22	remdesivir
# 18	23	remdesivir
# 18	25	remdesivir
# 18	26	remdesivir
# 18	28	remdesivir
# 18	30	remdesivir
# 18	32	remdesivir
# 18	33	remdesivir
# 18	34	remdesivir
# 21	22	remdesivir
# 21	23	remdesivir
# 21	25	remdesivir
# 21	26	remdesivir
# 21	28	remdesivir
# 21	30	remdesivir
# 21	32	remdesivir
# 21	33	remdesivir
# 21	34	remdesivir
# 22	23	remdesivir
# 22	25	remdesivir
# 22	26	remdesivir
# 22	28	remdesivir
# 22	30	remdesivir
# 22	32	remdesivir
# 22	33	remdesivir
# 22	34	remdesivir
# 23	25	remdesivir
# 23	26	remdesivir
# 23	28	remdesivir
# 23	30	remdesivir
# 23	32	remdesivir
# 23	33	remdesivir
# 23	34	remdesivir
# 25	26	remdesivir
# 25	28	remdesivir
# 25	30	remdesivir
# 25	32	remdesivir
# 25	33	remdesivir
# 25	34	remdesivir
# 26	28	remdesivir
# 26	30	remdesivir
# 26	32	remdesivir
# 26	33	remdesivir
# 26	34	remdesivir
# 28	30	remdesivir
# 28	32	remdesivir
# 28	33	remdesivir
# 28	34	remdesivir
# 30	32	remdesivir
# 30	33	remdesivir
# 30	34	remdesivir
# 32	33	remdesivir
# 32	34	remdesivir
# 33	34	remdesivir
# 25	26	nitazoxanide
# 25	32	nitazoxanide
# 26	32	nitazoxanide
# 5	5	hydrocortisone
# 7	11	mefloquine
# 7	23	mefloquine
# 7	26	mefloquine
# 11	23	mefloquine
# 11	26	mefloquine
# 23	26	mefloquine
# 19	26	bortezomib
# 29	34	phenol
# 9	33	potassium
# 19	19	benzodiazepine
# 11	11	ivacaftor
# 5	6	darunavir
# 5	12	darunavir
# 5	19	darunavir
# 5	20	darunavir
# 5	24	darunavir
# 5	25	darunavir
# 6	12	darunavir
# 6	19	darunavir
# 6	20	darunavir
# 6	24	darunavir
# 6	25	darunavir
# 12	19	darunavir
# 12	20	darunavir
# 12	24	darunavir
# 12	25	darunavir
# 19	20	darunavir
# 19	24	darunavir
# 19	25	darunavir
# 20	24	darunavir
# 20	25	darunavir
# 24	25	darunavir
# 12	12	vonoprazan
# 32	32	tenofovir
# 11	26	gilteritinib
# 12	12	ifenprodil
# 12	12	omeprazole
# 31	31	heparin
# 11	14	camostat
# 11	16	camostat
# 11	25	camostat
# 14	16	camostat
# 14	25	camostat
# 16	25	camostat
# 12	12	estradiol
# 5	6	methylprednisolone
# 5	21	methylprednisolone
# 6	21	methylprednisolone
# 7	26	emetine
# 12	12	ibudilast
# 28	28	carmofur
# 19	19	apixaban
# 19	19	argatroban
# 15	16	baicalin
# 19	19	rifampicin
# 28	28	ampicillin
# 19	20	telaprevir
# 5	5	andrographolide
# 7	26	fluspirilene
# 29	29	tryptophan
# 8	8	dipyridamole
# 12	20	dolutegravir
# 7	26	promethazine
# 10	10	nafamostat
# 26	26	alvocidib
# 19	19	lisinopril
# 12	12	dopamine
# 17	17	dactinomycin
# 4	20	efavirenz
# 11	23	cepharanthine
# 15	22	n3
# 15	28	n3
# 22	28	n3
# 4	4	nicotinamide
# 12	12	levofloxacin
# 9	13	alanine
# 3	4	sofosbuvir
# 3	21	sofosbuvir
# 4	21	sofosbuvir
# 1	5	arbidol
# 1	6	arbidol
# 1	10	arbidol
# 1	12	arbidol
# 1	13	arbidol
# 1	16	arbidol
# 1	25	arbidol
# 1	32	arbidol
# 5	6	arbidol
# 5	10	arbidol
# 5	12	arbidol
# 5	13	arbidol
# 5	16	arbidol
# 5	25	arbidol
# 5	32	arbidol
# 6	10	arbidol
# 6	12	arbidol
# 6	13	arbidol
# 6	16	arbidol
# 6	25	arbidol
# 6	32	arbidol
# 10	12	arbidol
# 10	13	arbidol
# 10	16	arbidol
# 10	25	arbidol
# 10	32	arbidol
# 12	13	arbidol
# 12	16	arbidol
# 12	25	arbidol
# 12	32	arbidol
# 13	16	arbidol
# 13	25	arbidol
# 13	32	arbidol
# 16	25	arbidol
# 16	32	arbidol
# 25	32	arbidol
# 26	26	tyloxapol
# 21	21	etoposide
# 13	13	creatine
# 12	12	naltrexone
# 11	11	proscillaridin
# 4	5	azithromycin
# 4	10	azithromycin
# 4	12	azithromycin
# 4	33	azithromycin
# 5	10	azithromycin
# 5	12	azithromycin
# 5	33	azithromycin
# 10	12	azithromycin
# 10	33	azithromycin
# 12	33	azithromycin
# 1	1	indomethacin
# 4	19	penicillin
# 4	26	penicillin
# 4	34	penicillin
# 19	26	penicillin
# 19	34	penicillin
# 26	34	penicillin
# 12	12	acetylcholine
# 12	28	glutathione
# 12	29	glutathione
# 12	34	glutathione
# 28	29	glutathione
# 28	34	glutathione
# 29	34	glutathione
# 17	17	mercaptopurine
# 11	11	digoxin
# 2	4	cysteine
# 2	14	cysteine
# 2	22	cysteine
# 2	25	cysteine
# 2	28	cysteine
# 2	29	cysteine
# 2	34	cysteine
# 4	14	cysteine
# 4	22	cysteine
# 4	25	cysteine
# 4	28	cysteine
# 4	29	cysteine
# 4	34	cysteine
# 14	22	cysteine
# 14	25	cysteine
# 14	28	cysteine
# 14	29	cysteine
# 14	34	cysteine
# 22	25	cysteine
# 22	28	cysteine
# 22	29	cysteine
# 22	34	cysteine
# 25	28	cysteine
# 25	29	cysteine
# 25	34	cysteine
# 28	29	cysteine
# 28	34	cysteine
# 29	34	cysteine
# 19	19	dapsone
# 19	20	boceprevir
# 26	26	ivermectin
# 11	11	osimertinib
# 12	12	alprostadil
# 19	19	atorvastatin
# 28	28	ebselen
# 5	5	pirfenidone
# 21	21	venetoclax
# 25	32	galidesivir
# 26	26	fluvastatin
# 12	12	isotretinoin
# 19	24	amprenavir
# 26	26	methotrexate
# 11	11	tetrandrine
# 21	29	arginine
# 21	34	arginine
# 29	34	arginine
# 7	26	terconazole
# 1	7	imatinib
# 1	26	imatinib
# 7	26	imatinib
# 1	25	baricitinib
# 1	26	baricitinib
# 25	26	baricitinib
# 7	26	clomipramine
# 16	18	doxycycline
# 5	5	dexamethasone
# 1	7	chlorpromazine
# 1	18	chlorpromazine
# 1	26	chlorpromazine
# 7	18	chlorpromazine
# 7	26	chlorpromazine
# 18	26	chlorpromazine
# 34	34	doxorubicin
# 34	34	metformin
# 19	19	rivaroxaban
# 5	20	cobicistat
# 20	20	acyclovir
# 7	10	tamoxifen
# 7	12	tamoxifen
# 7	17	tamoxifen
# 7	26	tamoxifen
# 10	12	tamoxifen
# 10	17	tamoxifen
# 10	26	tamoxifen
# 12	17	tamoxifen
# 12	26	tamoxifen
# 17	26	tamoxifen
# 1	1	curcumin
# 11	26	niclosamide
# 1	5	oseltamivir
# 1	10	oseltamivir
# 1	16	oseltamivir
# 1	32	oseltamivir
# 5	10	oseltamivir
# 5	16	oseltamivir
# 5	32	oseltamivir
# 10	16	oseltamivir
# 10	32	oseltamivir
# 16	32	oseltamivir
# 17	17	paroxetine
# 12	12	epinephrine
# 5	9	danoprevir
# 5	20	danoprevir
# 9	20	danoprevir
# 12	12	cisatracurium
# 20	20	raltegravir
# 1	14	adenosine
# 1	16	adenosine
# 1	32	adenosine
# 14	16	adenosine
# 14	32	adenosine
# 16	32	adenosine
# 3	5	ribavirin
# 3	9	ribavirin
# 3	14	ribavirin
# 3	16	ribavirin
# 3	18	ribavirin
# 3	21	ribavirin
# 3	25	ribavirin
# 3	26	ribavirin
# 3	30	ribavirin
# 3	32	ribavirin
# 5	9	ribavirin
# 5	14	ribavirin
# 5	16	ribavirin
# 5	18	ribavirin
# 5	21	ribavirin
# 5	25	ribavirin
# 5	26	ribavirin
# 5	30	ribavirin
# 5	32	ribavirin
# 9	14	ribavirin
# 9	16	ribavirin
# 9	18	ribavirin
# 9	21	ribavirin
# 9	25	ribavirin
# 9	26	ribavirin
# 9	30	ribavirin
# 9	32	ribavirin
# 14	16	ribavirin
# 14	18	ribavirin
# 14	21	ribavirin
# 14	25	ribavirin
# 14	26	ribavirin
# 14	30	ribavirin
# 14	32	ribavirin
# 16	18	ribavirin
# 16	21	ribavirin
# 16	25	ribavirin
# 16	26	ribavirin
# 16	30	ribavirin
# 16	32	ribavirin
# 18	21	ribavirin
# 18	25	ribavirin
# 18	26	ribavirin
# 18	30	ribavirin
# 18	32	ribavirin
# 21	25	ribavirin
# 21	26	ribavirin
# 21	30	ribavirin
# 21	32	ribavirin
# 25	26	ribavirin
# 25	30	ribavirin
# 25	32	ribavirin
# 26	30	ribavirin
# 26	32	ribavirin
# 30	32	ribavirin
# 17	17	aldosterone
# 14	14	glycine
# 13	13	sarilumab
# 2	4	ritonavir
# 2	5	ritonavir
# 2	6	ritonavir
# 2	9	ritonavir
# 2	16	ritonavir
# 2	19	ritonavir
# 2	20	ritonavir
# 2	21	ritonavir
# 2	24	ritonavir
# 2	25	ritonavir
# 2	26	ritonavir
# 2	30	ritonavir
# 2	32	ritonavir
# 4	5	ritonavir
# 4	6	ritonavir
# 4	9	ritonavir
# 4	16	ritonavir
# 4	19	ritonavir
# 4	20	ritonavir
# 4	21	ritonavir
# 4	24	ritonavir
# 4	25	ritonavir
# 4	26	ritonavir
# 4	30	ritonavir
# 4	32	ritonavir
# 5	6	ritonavir
# 5	9	ritonavir
# 5	16	ritonavir
# 5	19	ritonavir
# 5	20	ritonavir
# 5	21	ritonavir
# 5	24	ritonavir
# 5	25	ritonavir
# 5	26	ritonavir
# 5	30	ritonavir
# 5	32	ritonavir
# 6	9	ritonavir
# 6	16	ritonavir
# 6	19	ritonavir
# 6	20	ritonavir
# 6	21	ritonavir
# 6	24	ritonavir
# 6	25	ritonavir
# 6	26	ritonavir
# 6	30	ritonavir
# 6	32	ritonavir
# 9	16	ritonavir
# 9	19	ritonavir
# 9	20	ritonavir
# 9	21	ritonavir
# 9	24	ritonavir
# 9	25	ritonavir
# 9	26	ritonavir
# 9	30	ritonavir
# 9	32	ritonavir
# 16	19	ritonavir
# 16	20	ritonavir
# 16	21	ritonavir
# 16	24	ritonavir
# 16	25	ritonavir
# 16	26	ritonavir
# 16	30	ritonavir
# 16	32	ritonavir
# 19	20	ritonavir
# 19	21	ritonavir
# 19	24	ritonavir
# 19	25	ritonavir
# 19	26	ritonavir
# 19	30	ritonavir
# 19	32	ritonavir
# 20	21	ritonavir
# 20	24	ritonavir
# 20	25	ritonavir
# 20	26	ritonavir
# 20	30	ritonavir
# 20	32	ritonavir
# 21	24	ritonavir
# 21	25	ritonavir
# 21	26	ritonavir
# 21	30	ritonavir
# 21	32	ritonavir
# 24	25	ritonavir
# 24	26	ritonavir
# 24	30	ritonavir
# 24	32	ritonavir
# 25	26	ritonavir
# 25	30	ritonavir
# 25	32	ritonavir
# 26	30	ritonavir
# 26	32	ritonavir
# 30	32	ritonavir

# %%
'|'.join([x for x in all_drugs if x not in ['remdesivir', 'chloroquine', 'lopinavir', 'ritonavir', 'ribavirin']])
# Out:
# 'triparanol|toremifene|ciclesonide|thalidomide|proline|sorafenib|mesalazine|zanamivir|hydroxychloroquine|captopril|nelfinavir|amodiaquine|erythromycin|amiodarone|hesperidin|ponatinib|saquinavir|disulfiram|atazanavir|ibuprofen|montelukast|indinavir|tyrosine|methionine|thiamine|clofazimine|dasatinib|loperamide|hexachlorophene|ambroxol|melatonin|quercetin|urea|fingolimod|quinine|favipiravir|creatinine|emodin|amantadine|bromhexine|sirolimus|simeprevir|nitazoxanide|hydrocortisone|mefloquine|bortezomib|phenol|potassium|benzodiazepine|ivacaftor|darunavir|vonoprazan|tenofovir|gilteritinib|ifenprodil|omeprazole|heparin|camostat|estradiol|methylprednisolone|emetine|ibudilast|carmofur|apixaban|argatroban|baicalin|rifampicin|ampicillin|telaprevir|andrographolide|fluspirilene|tryptophan|dipyridamole|dolutegravir|promethazine|nafamostat|alvocidib|lisinopril|dopamine|dactinomycin|efavirenz|cepharanthine|n3|nicotinamide|levofloxacin|alanine|sofosbuvir|arbidol|tyloxapol|etoposide|creatine|naltrexone|proscillaridin|azithromycin|indomethacin|penicillin|acetylcholine|glutathione|mercaptopurine|digoxin|cysteine|dapsone|boceprevir|ivermectin|osimertinib|alprostadil|atorvastatin|ebselen|pirfenidone|venetoclax|galidesivir|fluvastatin|isotretinoin|amprenavir|methotrexate|tetrandrine|arginine|terconazole|imatinib|baricitinib|clomipramine|doxycycline|dexamethasone|chlorpromazine|doxorubicin|metformin|rivaroxaban|cobicistat|acyclovir|tamoxifen|curcumin|niclosamide|oseltamivir|paroxetine|epinephrine|danoprevir|cisatracurium|raltegravir|adenosine|aldosterone|glycine|sarilumab'

# %%
'|'.join(['remdesivir', 'chloroquine', 'lopinavir', 'ritonavir', 'ribavirin'])
# Out:
# 'remdesivir|chloroquine|lopinavir|ritonavir|ribavirin'

# %%
all_combi = []

# %%
for drug in drug_per_doc:
    combi = list(combinations(drug,2))
#         print(combi)
#         print('-'*70)
    all_combi.extend(combi)

# %%
all_combi
# Out:
# [('adenosine', 'arbidol'),
#  ('adenosine', 'baricitinib'),
#  ('adenosine', 'chloroquine'),
#  ('adenosine', 'chlorpromazine'),
#  ('adenosine', 'curcumin'),
#  ('adenosine', 'imatinib'),
#  ('adenosine', 'indomethacin'),
#  ('adenosine', 'oseltamivir'),
#  ('adenosine', 'remdesivir'),
#  ('adenosine', 'zanamivir'),
#  ('arbidol', 'baricitinib'),
#  ('arbidol', 'chloroquine'),
#  ('arbidol', 'chlorpromazine'),
#  ('arbidol', 'curcumin'),
#  ('arbidol', 'imatinib'),
#  ('arbidol', 'indomethacin'),
#  ('arbidol', 'oseltamivir'),
#  ('arbidol', 'remdesivir'),
#  ('arbidol', 'zanamivir'),
#  ('baricitinib', 'chloroquine'),
#  ('baricitinib', 'chlorpromazine'),
#  ('baricitinib', 'curcumin'),
#  ('baricitinib', 'imatinib'),
#  ('baricitinib', 'indomethacin'),
#  ('baricitinib', 'oseltamivir'),
#  ('baricitinib', 'remdesivir'),
#  ('baricitinib', 'zanamivir'),
#  ('chloroquine', 'chlorpromazine'),
#  ('chloroquine', 'curcumin'),
#  ('chloroquine', 'imatinib'),
#  ('chloroquine', 'indomethacin'),
#  ('chloroquine', 'oseltamivir'),
#  ('chloroquine', 'remdesivir'),
#  ('chloroquine', 'zanamivir'),
#  ('chlorpromazine', 'curcumin'),
#  ('chlorpromazine', 'imatinib'),
#  ('chlorpromazine', 'indomethacin'),
#  ('chlorpromazine', 'oseltamivir'),
#  ('chlorpromazine', 'remdesivir'),
#  ('chlorpromazine', 'zanamivir'),
#  ('curcumin', 'imatinib'),
#  ('curcumin', 'indomethacin'),
#  ('curcumin', 'oseltamivir'),
#  ('curcumin', 'remdesivir'),
#  ('curcumin', 'zanamivir'),
#  ('imatinib', 'indomethacin'),
#  ('imatinib', 'oseltamivir'),
#  ('imatinib', 'remdesivir'),
#  ('imatinib', 'zanamivir'),
#  ('indomethacin', 'oseltamivir'),
#  ('indomethacin', 'remdesivir'),
#  ('indomethacin', 'zanamivir'),
#  ('oseltamivir', 'remdesivir'),
#  ('oseltamivir', 'zanamivir'),
#  ('remdesivir', 'zanamivir'),
#  ('cysteine', 'lopinavir'),
#  ('cysteine', 'ponatinib'),
#  ('cysteine', 'ritonavir'),
#  ('lopinavir', 'ponatinib'),
#  ('lopinavir', 'ritonavir'),
#  ('ponatinib', 'ritonavir'),
#  ('chloroquine', 'favipiravir'),
#  ('chloroquine', 'remdesivir'),
#  ('chloroquine', 'ribavirin'),
#  ('chloroquine', 'sofosbuvir'),
#  ('favipiravir', 'remdesivir'),
#  ('favipiravir', 'ribavirin'),
#  ('favipiravir', 'sofosbuvir'),
#  ('remdesivir', 'ribavirin'),
#  ('remdesivir', 'sofosbuvir'),
#  ('ribavirin', 'sofosbuvir'),
#  ('atazanavir', 'azithromycin'),
#  ('atazanavir', 'chloroquine'),
#  ('atazanavir', 'cysteine'),
#  ('atazanavir', 'efavirenz'),
#  ('atazanavir', 'hydroxychloroquine'),
#  ('atazanavir', 'indinavir'),
#  ('atazanavir', 'lopinavir'),
#  ('atazanavir', 'nicotinamide'),
#  ('atazanavir', 'penicillin'),
#  ('atazanavir', 'remdesivir'),
#  ('atazanavir', 'ritonavir'),
#  ('atazanavir', 'sofosbuvir'),
#  ('azithromycin', 'chloroquine'),
#  ('azithromycin', 'cysteine'),
#  ('azithromycin', 'efavirenz'),
#  ('azithromycin', 'hydroxychloroquine'),
#  ('azithromycin', 'indinavir'),
#  ('azithromycin', 'lopinavir'),
#  ('azithromycin', 'nicotinamide'),
#  ('azithromycin', 'penicillin'),
#  ('azithromycin', 'remdesivir'),
#  ('azithromycin', 'ritonavir'),
#  ('azithromycin', 'sofosbuvir'),
#  ('chloroquine', 'cysteine'),
#  ('chloroquine', 'efavirenz'),
#  ('chloroquine', 'hydroxychloroquine'),
#  ('chloroquine', 'indinavir'),
#  ('chloroquine', 'lopinavir'),
#  ('chloroquine', 'nicotinamide'),
#  ('chloroquine', 'penicillin'),
#  ('chloroquine', 'remdesivir'),
#  ('chloroquine', 'ritonavir'),
#  ('chloroquine', 'sofosbuvir'),
#  ('cysteine', 'efavirenz'),
#  ('cysteine', 'hydroxychloroquine'),
#  ('cysteine', 'indinavir'),
#  ('cysteine', 'lopinavir'),
#  ('cysteine', 'nicotinamide'),
#  ('cysteine', 'penicillin'),
#  ('cysteine', 'remdesivir'),
#  ('cysteine', 'ritonavir'),
#  ('cysteine', 'sofosbuvir'),
#  ('efavirenz', 'hydroxychloroquine'),
#  ('efavirenz', 'indinavir'),
#  ('efavirenz', 'lopinavir'),
#  ('efavirenz', 'nicotinamide'),
#  ('efavirenz', 'penicillin'),
#  ('efavirenz', 'remdesivir'),
#  ('efavirenz', 'ritonavir'),
#  ('efavirenz', 'sofosbuvir'),
#  ('hydroxychloroquine', 'indinavir'),
#  ('hydroxychloroquine', 'lopinavir'),
#  ('hydroxychloroquine', 'nicotinamide'),
#  ('hydroxychloroquine', 'penicillin'),
#  ('hydroxychloroquine', 'remdesivir'),
#  ('hydroxychloroquine', 'ritonavir'),
#  ('hydroxychloroquine', 'sofosbuvir'),
#  ('indinavir', 'lopinavir'),
#  ('indinavir', 'nicotinamide'),
#  ('indinavir', 'penicillin'),
#  ('indinavir', 'remdesivir'),
#  ('indinavir', 'ritonavir'),
#  ('indinavir', 'sofosbuvir'),
#  ('lopinavir', 'nicotinamide'),
#  ('lopinavir', 'penicillin'),
#  ('lopinavir', 'remdesivir'),
#  ('lopinavir', 'ritonavir'),
#  ('lopinavir', 'sofosbuvir'),
#  ('nicotinamide', 'penicillin'),
#  ('nicotinamide', 'remdesivir'),
#  ('nicotinamide', 'ritonavir'),
#  ('nicotinamide', 'sofosbuvir'),
#  ('penicillin', 'remdesivir'),
#  ('penicillin', 'ritonavir'),
#  ('penicillin', 'sofosbuvir'),
#  ('remdesivir', 'ritonavir'),
#  ('remdesivir', 'sofosbuvir'),
#  ('ritonavir', 'sofosbuvir'),
#  ('andrographolide', 'arbidol'),
#  ('andrographolide', 'azithromycin'),
#  ('andrographolide', 'bromhexine'),
#  ('andrographolide', 'chloroquine'),
#  ('andrographolide', 'cobicistat'),
#  ('andrographolide', 'danoprevir'),
#  ('andrographolide', 'darunavir'),
#  ('andrographolide', 'dexamethasone'),
#  ('andrographolide', 'favipiravir'),
#  ('andrographolide', 'fingolimod'),
#  ('andrographolide', 'hydrocortisone'),
#  ('andrographolide', 'hydroxychloroquine'),
#  ('andrographolide', 'lopinavir'),
#  ('andrographolide', 'methylprednisolone'),
#  ('andrographolide', 'oseltamivir'),
#  ('andrographolide', 'pirfenidone'),
#  ('andrographolide', 'remdesivir'),
#  ('andrographolide', 'ribavirin'),
#  ('andrographolide', 'ritonavir'),
#  ('andrographolide', 'thalidomide'),
#  ('arbidol', 'azithromycin'),
#  ('arbidol', 'bromhexine'),
#  ('arbidol', 'chloroquine'),
#  ('arbidol', 'cobicistat'),
#  ('arbidol', 'danoprevir'),
#  ('arbidol', 'darunavir'),
#  ('arbidol', 'dexamethasone'),
#  ('arbidol', 'favipiravir'),
#  ('arbidol', 'fingolimod'),
#  ('arbidol', 'hydrocortisone'),
#  ('arbidol', 'hydroxychloroquine'),
#  ('arbidol', 'lopinavir'),
#  ('arbidol', 'methylprednisolone'),
#  ('arbidol', 'oseltamivir'),
#  ('arbidol', 'pirfenidone'),
#  ('arbidol', 'remdesivir'),
#  ('arbidol', 'ribavirin'),
#  ('arbidol', 'ritonavir'),
#  ('arbidol', 'thalidomide'),
#  ('azithromycin', 'bromhexine'),
#  ('azithromycin', 'chloroquine'),
#  ('azithromycin', 'cobicistat'),
#  ('azithromycin', 'danoprevir'),
#  ('azithromycin', 'darunavir'),
#  ('azithromycin', 'dexamethasone'),
#  ('azithromycin', 'favipiravir'),
#  ('azithromycin', 'fingolimod'),
#  ('azithromycin', 'hydrocortisone'),
#  ('azithromycin', 'hydroxychloroquine'),
#  ('azithromycin', 'lopinavir'),
#  ('azithromycin', 'methylprednisolone'),
#  ('azithromycin', 'oseltamivir'),
#  ('azithromycin', 'pirfenidone'),
#  ('azithromycin', 'remdesivir'),
#  ('azithromycin', 'ribavirin'),
#  ('azithromycin', 'ritonavir'),
#  ('azithromycin', 'thalidomide'),
#  ('bromhexine', 'chloroquine'),
#  ('bromhexine', 'cobicistat'),
#  ('bromhexine', 'danoprevir'),
#  ('bromhexine', 'darunavir'),
#  ('bromhexine', 'dexamethasone'),
#  ('bromhexine', 'favipiravir'),
#  ('bromhexine', 'fingolimod'),
#  ('bromhexine', 'hydrocortisone'),
#  ('bromhexine', 'hydroxychloroquine'),
#  ('bromhexine', 'lopinavir'),
#  ('bromhexine', 'methylprednisolone'),
#  ('bromhexine', 'oseltamivir'),
#  ('bromhexine', 'pirfenidone'),
#  ('bromhexine', 'remdesivir'),
#  ('bromhexine', 'ribavirin'),
#  ('bromhexine', 'ritonavir'),
#  ('bromhexine', 'thalidomide'),
#  ('chloroquine', 'cobicistat'),
#  ('chloroquine', 'danoprevir'),
#  ('chloroquine', 'darunavir'),
#  ('chloroquine', 'dexamethasone'),
#  ('chloroquine', 'favipiravir'),
#  ('chloroquine', 'fingolimod'),
#  ('chloroquine', 'hydrocortisone'),
#  ('chloroquine', 'hydroxychloroquine'),
#  ('chloroquine', 'lopinavir'),
#  ('chloroquine', 'methylprednisolone'),
#  ('chloroquine', 'oseltamivir'),
#  ('chloroquine', 'pirfenidone'),
#  ('chloroquine', 'remdesivir'),
#  ('chloroquine', 'ribavirin'),
#  ('chloroquine', 'ritonavir'),
#  ('chloroquine', 'thalidomide'),
#  ('cobicistat', 'danoprevir'),
#  ('cobicistat', 'darunavir'),
#  ('cobicistat', 'dexamethasone'),
#  ('cobicistat', 'favipiravir'),
#  ('cobicistat', 'fingolimod'),
#  ('cobicistat', 'hydrocortisone'),
#  ('cobicistat', 'hydroxychloroquine'),
#  ('cobicistat', 'lopinavir'),
#  ('cobicistat', 'methylprednisolone'),
#  ('cobicistat', 'oseltamivir'),
#  ('cobicistat', 'pirfenidone'),
#  ('cobicistat', 'remdesivir'),
#  ('cobicistat', 'ribavirin'),
#  ('cobicistat', 'ritonavir'),
#  ('cobicistat', 'thalidomide'),
#  ('danoprevir', 'darunavir'),
#  ('danoprevir', 'dexamethasone'),
#  ('danoprevir', 'favipiravir'),
#  ('danoprevir', 'fingolimod'),
#  ('danoprevir', 'hydrocortisone'),
#  ('danoprevir', 'hydroxychloroquine'),
#  ('danoprevir', 'lopinavir'),
#  ('danoprevir', 'methylprednisolone'),
#  ('danoprevir', 'oseltamivir'),
#  ('danoprevir', 'pirfenidone'),
#  ('danoprevir', 'remdesivir'),
#  ('danoprevir', 'ribavirin'),
#  ('danoprevir', 'ritonavir'),
#  ('danoprevir', 'thalidomide'),
#  ('darunavir', 'dexamethasone'),
#  ('darunavir', 'favipiravir'),
#  ('darunavir', 'fingolimod'),
#  ('darunavir', 'hydrocortisone'),
#  ('darunavir', 'hydroxychloroquine'),
#  ('darunavir', 'lopinavir'),
#  ('darunavir', 'methylprednisolone'),
#  ('darunavir', 'oseltamivir'),
#  ('darunavir', 'pirfenidone'),
#  ('darunavir', 'remdesivir'),
#  ('darunavir', 'ribavirin'),
#  ('darunavir', 'ritonavir'),
#  ('darunavir', 'thalidomide'),
#  ('dexamethasone', 'favipiravir'),
#  ('dexamethasone', 'fingolimod'),
#  ('dexamethasone', 'hydrocortisone'),
#  ('dexamethasone', 'hydroxychloroquine'),
#  ('dexamethasone', 'lopinavir'),
#  ('dexamethasone', 'methylprednisolone'),
#  ('dexamethasone', 'oseltamivir'),
#  ('dexamethasone', 'pirfenidone'),
#  ('dexamethasone', 'remdesivir'),
#  ('dexamethasone', 'ribavirin'),
#  ('dexamethasone', 'ritonavir'),
#  ('dexamethasone', 'thalidomide'),
#  ('favipiravir', 'fingolimod'),
#  ('favipiravir', 'hydrocortisone'),
#  ('favipiravir', 'hydroxychloroquine'),
#  ('favipiravir', 'lopinavir'),
#  ('favipiravir', 'methylprednisolone'),
#  ('favipiravir', 'oseltamivir'),
#  ('favipiravir', 'pirfenidone'),
#  ('favipiravir', 'remdesivir'),
#  ('favipiravir', 'ribavirin'),
#  ('favipiravir', 'ritonavir'),
#  ('favipiravir', 'thalidomide'),
#  ('fingolimod', 'hydrocortisone'),
#  ('fingolimod', 'hydroxychloroquine'),
#  ('fingolimod', 'lopinavir'),
#  ('fingolimod', 'methylprednisolone'),
#  ('fingolimod', 'oseltamivir'),
#  ('fingolimod', 'pirfenidone'),
#  ('fingolimod', 'remdesivir'),
#  ('fingolimod', 'ribavirin'),
#  ('fingolimod', 'ritonavir'),
#  ('fingolimod', 'thalidomide'),
#  ('hydrocortisone', 'hydroxychloroquine'),
#  ('hydrocortisone', 'lopinavir'),
#  ('hydrocortisone', 'methylprednisolone'),
#  ('hydrocortisone', 'oseltamivir'),
#  ('hydrocortisone', 'pirfenidone'),
#  ('hydrocortisone', 'remdesivir'),
#  ('hydrocortisone', 'ribavirin'),
#  ('hydrocortisone', 'ritonavir'),
#  ('hydrocortisone', 'thalidomide'),
#  ('hydroxychloroquine', 'lopinavir'),
#  ('hydroxychloroquine', 'methylprednisolone'),
#  ('hydroxychloroquine', 'oseltamivir'),
#  ('hydroxychloroquine', 'pirfenidone'),
#  ('hydroxychloroquine', 'remdesivir'),
#  ('hydroxychloroquine', 'ribavirin'),
#  ('hydroxychloroquine', 'ritonavir'),
#  ('hydroxychloroquine', 'thalidomide'),
#  ('lopinavir', 'methylprednisolone'),
#  ('lopinavir', 'oseltamivir'),
#  ('lopinavir', 'pirfenidone'),
#  ('lopinavir', 'remdesivir'),
#  ('lopinavir', 'ribavirin'),
#  ('lopinavir', 'ritonavir'),
#  ('lopinavir', 'thalidomide'),
#  ('methylprednisolone', 'oseltamivir'),
#  ('methylprednisolone', 'pirfenidone'),
#  ('methylprednisolone', 'remdesivir'),
#  ('methylprednisolone', 'ribavirin'),
#  ('methylprednisolone', 'ritonavir'),
#  ('methylprednisolone', 'thalidomide'),
#  ('oseltamivir', 'pirfenidone'),
#  ('oseltamivir', 'remdesivir'),
#  ('oseltamivir', 'ribavirin'),
#  ('oseltamivir', 'ritonavir'),
#  ('oseltamivir', 'thalidomide'),
#  ('pirfenidone', 'remdesivir'),
#  ('pirfenidone', 'ribavirin'),
#  ('pirfenidone', 'ritonavir'),
#  ('pirfenidone', 'thalidomide'),
#  ('remdesivir', 'ribavirin'),
#  ('remdesivir', 'ritonavir'),
#  ('remdesivir', 'thalidomide'),
#  ('ribavirin', 'ritonavir'),
#  ('ribavirin', 'thalidomide'),
#  ('ritonavir', 'thalidomide'),
#  ('arbidol', 'darunavir'),
#  ('arbidol', 'favipiravir'),
#  ('arbidol', 'lopinavir'),
#  ('arbidol', 'methylprednisolone'),
#  ('arbidol', 'ritonavir'),
#  ('darunavir', 'favipiravir'),
#  ('darunavir', 'lopinavir'),
#  ('darunavir', 'methylprednisolone'),
#  ('darunavir', 'ritonavir'),
#  ('favipiravir', 'lopinavir'),
#  ('favipiravir', 'methylprednisolone'),
#  ('favipiravir', 'ritonavir'),
#  ('lopinavir', 'methylprednisolone'),
#  ('lopinavir', 'ritonavir'),
#  ('methylprednisolone', 'ritonavir'),
#  ('amiodarone', 'chloroquine'),
#  ('amiodarone', 'chlorpromazine'),
#  ('amiodarone', 'clomipramine'),
#  ('amiodarone', 'emetine'),
#  ('amiodarone', 'fluspirilene'),
#  ('amiodarone', 'hydroxychloroquine'),
#  ('amiodarone', 'imatinib'),
#  ('amiodarone', 'mefloquine'),
#  ('amiodarone', 'promethazine'),
#  ('amiodarone', 'tamoxifen'),
#  ('amiodarone', 'terconazole'),
#  ('amiodarone', 'toremifene'),
#  ('amiodarone', 'triparanol'),
#  ('chloroquine', 'chlorpromazine'),
#  ('chloroquine', 'clomipramine'),
#  ('chloroquine', 'emetine'),
#  ('chloroquine', 'fluspirilene'),
#  ('chloroquine', 'hydroxychloroquine'),
#  ('chloroquine', 'imatinib'),
#  ('chloroquine', 'mefloquine'),
#  ('chloroquine', 'promethazine'),
#  ('chloroquine', 'tamoxifen'),
#  ('chloroquine', 'terconazole'),
#  ('chloroquine', 'toremifene'),
#  ('chloroquine', 'triparanol'),
#  ('chlorpromazine', 'clomipramine'),
#  ('chlorpromazine', 'emetine'),
#  ('chlorpromazine', 'fluspirilene'),
#  ('chlorpromazine', 'hydroxychloroquine'),
#  ('chlorpromazine', 'imatinib'),
#  ('chlorpromazine', 'mefloquine'),
#  ('chlorpromazine', 'promethazine'),
#  ('chlorpromazine', 'tamoxifen'),
#  ('chlorpromazine', 'terconazole'),
#  ('chlorpromazine', 'toremifene'),
#  ('chlorpromazine', 'triparanol'),
#  ('clomipramine', 'emetine'),
#  ('clomipramine', 'fluspirilene'),
#  ('clomipramine', 'hydroxychloroquine'),
#  ('clomipramine', 'imatinib'),
#  ('clomipramine', 'mefloquine'),
#  ('clomipramine', 'promethazine'),
#  ('clomipramine', 'tamoxifen'),
#  ('clomipramine', 'terconazole'),
#  ('clomipramine', 'toremifene'),
#  ('clomipramine', 'triparanol'),
#  ('emetine', 'fluspirilene'),
#  ('emetine', 'hydroxychloroquine'),
#  ('emetine', 'imatinib'),
#  ('emetine', 'mefloquine'),
#  ('emetine', 'promethazine'),
#  ('emetine', 'tamoxifen'),
#  ('emetine', 'terconazole'),
#  ('emetine', 'toremifene'),
#  ('emetine', 'triparanol'),
#  ('fluspirilene', 'hydroxychloroquine'),
#  ('fluspirilene', 'imatinib'),
#  ('fluspirilene', 'mefloquine'),
#  ('fluspirilene', 'promethazine'),
#  ('fluspirilene', 'tamoxifen'),
#  ('fluspirilene', 'terconazole'),
#  ('fluspirilene', 'toremifene'),
#  ('fluspirilene', 'triparanol'),
#  ('hydroxychloroquine', 'imatinib'),
#  ('hydroxychloroquine', 'mefloquine'),
#  ('hydroxychloroquine', 'promethazine'),
#  ('hydroxychloroquine', 'tamoxifen'),
#  ('hydroxychloroquine', 'terconazole'),
#  ('hydroxychloroquine', 'toremifene'),
#  ('hydroxychloroquine', 'triparanol'),
#  ('imatinib', 'mefloquine'),
#  ('imatinib', 'promethazine'),
#  ('imatinib', 'tamoxifen'),
#  ('imatinib', 'terconazole'),
#  ('imatinib', 'toremifene'),
#  ('imatinib', 'triparanol'),
#  ('mefloquine', 'promethazine'),
#  ('mefloquine', 'tamoxifen'),
#  ('mefloquine', 'terconazole'),
#  ('mefloquine', 'toremifene'),
#  ('mefloquine', 'triparanol'),
#  ('promethazine', 'tamoxifen'),
#  ('promethazine', 'terconazole'),
#  ('promethazine', 'toremifene'),
#  ('promethazine', 'triparanol'),
#  ('tamoxifen', 'terconazole'),
#  ('tamoxifen', 'toremifene'),
#  ('tamoxifen', 'triparanol'),
#  ('terconazole', 'toremifene'),
#  ('terconazole', 'triparanol'),
#  ('toremifene', 'triparanol'),
#  ('atazanavir', 'chloroquine'),
#  ('atazanavir', 'dipyridamole'),
#  ('atazanavir', 'disulfiram'),
#  ('atazanavir', 'indinavir'),
#  ('atazanavir', 'montelukast'),
#  ('atazanavir', 'remdesivir'),
#  ('chloroquine', 'dipyridamole'),
#  ('chloroquine', 'disulfiram'),
#  ('chloroquine', 'indinavir'),
#  ('chloroquine', 'montelukast'),
#  ('chloroquine', 'remdesivir'),
#  ('dipyridamole', 'disulfiram'),
#  ('dipyridamole', 'indinavir'),
#  ('dipyridamole', 'montelukast'),
#  ('dipyridamole', 'remdesivir'),
#  ('disulfiram', 'indinavir'),
#  ('disulfiram', 'montelukast'),
#  ('disulfiram', 'remdesivir'),
#  ('indinavir', 'montelukast'),
#  ('indinavir', 'remdesivir'),
#  ('montelukast', 'remdesivir'),
#  ('alanine', 'creatinine'),
#  ('alanine', 'danoprevir'),
#  ('alanine', 'lopinavir'),
#  ('alanine', 'potassium'),
#  ('alanine', 'remdesivir'),
#  ('alanine', 'ribavirin'),
#  ('alanine', 'ritonavir'),
#  ('alanine', 'urea'),
#  ('creatinine', 'danoprevir'),
#  ('creatinine', 'lopinavir'),
#  ('creatinine', 'potassium'),
#  ('creatinine', 'remdesivir'),
#  ('creatinine', 'ribavirin'),
#  ('creatinine', 'ritonavir'),
#  ('creatinine', 'urea'),
#  ('danoprevir', 'lopinavir'),
#  ('danoprevir', 'potassium'),
#  ('danoprevir', 'remdesivir'),
#  ('danoprevir', 'ribavirin'),
#  ('danoprevir', 'ritonavir'),
#  ('danoprevir', 'urea'),
#  ('lopinavir', 'potassium'),
#  ('lopinavir', 'remdesivir'),
#  ('lopinavir', 'ribavirin'),
#  ('lopinavir', 'ritonavir'),
#  ('lopinavir', 'urea'),
#  ('potassium', 'remdesivir'),
#  ('potassium', 'ribavirin'),
#  ('potassium', 'ritonavir'),
#  ('potassium', 'urea'),
#  ('remdesivir', 'ribavirin'),
#  ('remdesivir', 'ritonavir'),
#  ('remdesivir', 'urea'),
#  ('ribavirin', 'ritonavir'),
#  ('ribavirin', 'urea'),
#  ('ritonavir', 'urea'),
#  ('amiodarone', 'amodiaquine'),
#  ('amiodarone', 'arbidol'),
#  ('amiodarone', 'azithromycin'),
#  ('amiodarone', 'chloroquine'),
#  ('amiodarone', 'hydroxychloroquine'),
#  ('amiodarone', 'nafamostat'),
#  ('amiodarone', 'oseltamivir'),
#  ('amiodarone', 'remdesivir'),
#  ('amiodarone', 'tamoxifen'),
#  ('amiodarone', 'toremifene'),
#  ('amodiaquine', 'arbidol'),
#  ('amodiaquine', 'azithromycin'),
#  ('amodiaquine', 'chloroquine'),
#  ('amodiaquine', 'hydroxychloroquine'),
#  ('amodiaquine', 'nafamostat'),
#  ('amodiaquine', 'oseltamivir'),
#  ('amodiaquine', 'remdesivir'),
#  ('amodiaquine', 'tamoxifen'),
#  ('amodiaquine', 'toremifene'),
#  ('arbidol', 'azithromycin'),
#  ('arbidol', 'chloroquine'),
#  ('arbidol', 'hydroxychloroquine'),
#  ('arbidol', 'nafamostat'),
#  ('arbidol', 'oseltamivir'),
#  ('arbidol', 'remdesivir'),
#  ('arbidol', 'tamoxifen'),
#  ('arbidol', 'toremifene'),
#  ('azithromycin', 'chloroquine'),
#  ('azithromycin', 'hydroxychloroquine'),
#  ('azithromycin', 'nafamostat'),
#  ('azithromycin', 'oseltamivir'),
#  ('azithromycin', 'remdesivir'),
#  ('azithromycin', 'tamoxifen'),
#  ('azithromycin', 'toremifene'),
#  ('chloroquine', 'hydroxychloroquine'),
#  ('chloroquine', 'nafamostat'),
#  ('chloroquine', 'oseltamivir'),
#  ('chloroquine', 'remdesivir'),
#  ('chloroquine', 'tamoxifen'),
#  ('chloroquine', 'toremifene'),
#  ('hydroxychloroquine', 'nafamostat'),
#  ('hydroxychloroquine', 'oseltamivir'),
#  ('hydroxychloroquine', 'remdesivir'),
#  ('hydroxychloroquine', 'tamoxifen'),
#  ('hydroxychloroquine', 'toremifene'),
#  ('nafamostat', 'oseltamivir'),
#  ('nafamostat', 'remdesivir'),
#  ('nafamostat', 'tamoxifen'),
#  ('nafamostat', 'toremifene'),
#  ('oseltamivir', 'remdesivir'),
#  ('oseltamivir', 'tamoxifen'),
#  ('oseltamivir', 'toremifene'),
#  ('remdesivir', 'tamoxifen'),
#  ('remdesivir', 'toremifene'),
#  ('tamoxifen', 'toremifene'),
#  ('amodiaquine', 'atazanavir'),
#  ('amodiaquine', 'camostat'),
#  ('amodiaquine', 'cepharanthine'),
#  ('amodiaquine', 'chloroquine'),
#  ('amodiaquine', 'ciclesonide'),
#  ('amodiaquine', 'digoxin'),
#  ('amodiaquine', 'favipiravir'),
#  ('amodiaquine', 'gilteritinib'),
#  ('amodiaquine', 'hexachlorophene'),
#  ('amodiaquine', 'hexachlorophene'),
#  ('amodiaquine', 'ivacaftor'),
#  ('amodiaquine', 'loperamide'),
#  ('amodiaquine', 'lopinavir'),
#  ('amodiaquine', 'mefloquine'),
#  ('amodiaquine', 'niclosamide'),
#  ('amodiaquine', 'osimertinib'),
#  ('amodiaquine', 'proscillaridin'),
#  ('amodiaquine', 'remdesivir'),
#  ('amodiaquine', 'tetrandrine'),
#  ('amodiaquine', 'triparanol'),
#  ('atazanavir', 'camostat'),
#  ('atazanavir', 'cepharanthine'),
#  ('atazanavir', 'chloroquine'),
#  ('atazanavir', 'ciclesonide'),
#  ('atazanavir', 'digoxin'),
#  ('atazanavir', 'favipiravir'),
#  ('atazanavir', 'gilteritinib'),
#  ('atazanavir', 'hexachlorophene'),
#  ('atazanavir', 'hexachlorophene'),
#  ('atazanavir', 'ivacaftor'),
#  ('atazanavir', 'loperamide'),
#  ('atazanavir', 'lopinavir'),
#  ('atazanavir', 'mefloquine'),
#  ('atazanavir', 'niclosamide'),
#  ('atazanavir', 'osimertinib'),
#  ('atazanavir', 'proscillaridin'),
#  ('atazanavir', 'remdesivir'),
#  ('atazanavir', 'tetrandrine'),
#  ('atazanavir', 'triparanol'),
#  ('camostat', 'cepharanthine'),
#  ('camostat', 'chloroquine'),
#  ('camostat', 'ciclesonide'),
#  ('camostat', 'digoxin'),
#  ('camostat', 'favipiravir'),
#  ('camostat', 'gilteritinib'),
#  ('camostat', 'hexachlorophene'),
#  ('camostat', 'hexachlorophene'),
#  ('camostat', 'ivacaftor'),
#  ('camostat', 'loperamide'),
#  ('camostat', 'lopinavir'),
#  ('camostat', 'mefloquine'),
#  ('camostat', 'niclosamide'),
#  ('camostat', 'osimertinib'),
#  ('camostat', 'proscillaridin'),
#  ('camostat', 'remdesivir'),
#  ('camostat', 'tetrandrine'),
#  ('camostat', 'triparanol'),
#  ('cepharanthine', 'chloroquine'),
#  ('cepharanthine', 'ciclesonide'),
#  ('cepharanthine', 'digoxin'),
#  ('cepharanthine', 'favipiravir'),
#  ('cepharanthine', 'gilteritinib'),
#  ('cepharanthine', 'hexachlorophene'),
#  ('cepharanthine', 'hexachlorophene'),
#  ('cepharanthine', 'ivacaftor'),
#  ('cepharanthine', 'loperamide'),
#  ('cepharanthine', 'lopinavir'),
#  ('cepharanthine', 'mefloquine'),
#  ('cepharanthine', 'niclosamide'),
#  ('cepharanthine', 'osimertinib'),
#  ('cepharanthine', 'proscillaridin'),
#  ('cepharanthine', 'remdesivir'),
#  ('cepharanthine', 'tetrandrine'),
#  ('cepharanthine', 'triparanol'),
#  ('chloroquine', 'ciclesonide'),
#  ('chloroquine', 'digoxin'),
#  ('chloroquine', 'favipiravir'),
#  ('chloroquine', 'gilteritinib'),
#  ('chloroquine', 'hexachlorophene'),
#  ('chloroquine', 'hexachlorophene'),
#  ('chloroquine', 'ivacaftor'),
#  ('chloroquine', 'loperamide'),
#  ('chloroquine', 'lopinavir'),
#  ('chloroquine', 'mefloquine'),
#  ('chloroquine', 'niclosamide'),
#  ('chloroquine', 'osimertinib'),
#  ('chloroquine', 'proscillaridin'),
#  ('chloroquine', 'remdesivir'),
#  ('chloroquine', 'tetrandrine'),
#  ('chloroquine', 'triparanol'),
#  ('ciclesonide', 'digoxin'),
#  ('ciclesonide', 'favipiravir'),
#  ('ciclesonide', 'gilteritinib'),
#  ('ciclesonide', 'hexachlorophene'),
#  ('ciclesonide', 'hexachlorophene'),
#  ('ciclesonide', 'ivacaftor'),
#  ('ciclesonide', 'loperamide'),
#  ('ciclesonide', 'lopinavir'),
#  ('ciclesonide', 'mefloquine'),
#  ('ciclesonide', 'niclosamide'),
#  ('ciclesonide', 'osimertinib'),
#  ('ciclesonide', 'proscillaridin'),
#  ('ciclesonide', 'remdesivir'),
#  ('ciclesonide', 'tetrandrine'),
#  ('ciclesonide', 'triparanol'),
#  ('digoxin', 'favipiravir'),
#  ('digoxin', 'gilteritinib'),
#  ('digoxin', 'hexachlorophene'),
#  ('digoxin', 'hexachlorophene'),
#  ('digoxin', 'ivacaftor'),
#  ('digoxin', 'loperamide'),
#  ('digoxin', 'lopinavir'),
#  ('digoxin', 'mefloquine'),
#  ('digoxin', 'niclosamide'),
#  ('digoxin', 'osimertinib'),
#  ('digoxin', 'proscillaridin'),
#  ('digoxin', 'remdesivir'),
#  ('digoxin', 'tetrandrine'),
#  ('digoxin', 'triparanol'),
#  ('favipiravir', 'gilteritinib'),
#  ('favipiravir', 'hexachlorophene'),
#  ('favipiravir', 'hexachlorophene'),
#  ('favipiravir', 'ivacaftor'),
#  ('favipiravir', 'loperamide'),
#  ('favipiravir', 'lopinavir'),
#  ('favipiravir', 'mefloquine'),
#  ('favipiravir', 'niclosamide'),
#  ('favipiravir', 'osimertinib'),
#  ('favipiravir', 'proscillaridin'),
#  ('favipiravir', 'remdesivir'),
#  ('favipiravir', 'tetrandrine'),
#  ('favipiravir', 'triparanol'),
#  ('gilteritinib', 'hexachlorophene'),
#  ('gilteritinib', 'hexachlorophene'),
#  ('gilteritinib', 'ivacaftor'),
#  ('gilteritinib', 'loperamide'),
#  ('gilteritinib', 'lopinavir'),
#  ('gilteritinib', 'mefloquine'),
#  ('gilteritinib', 'niclosamide'),
#  ('gilteritinib', 'osimertinib'),
#  ('gilteritinib', 'proscillaridin'),
#  ('gilteritinib', 'remdesivir'),
#  ('gilteritinib', 'tetrandrine'),
#  ('gilteritinib', 'triparanol'),
#  ('hexachlorophene', 'hexachlorophene'),
#  ('hexachlorophene', 'ivacaftor'),
#  ('hexachlorophene', 'loperamide'),
#  ('hexachlorophene', 'lopinavir'),
#  ('hexachlorophene', 'mefloquine'),
#  ('hexachlorophene', 'niclosamide'),
#  ('hexachlorophene', 'osimertinib'),
#  ('hexachlorophene', 'proscillaridin'),
#  ('hexachlorophene', 'remdesivir'),
#  ('hexachlorophene', 'tetrandrine'),
#  ('hexachlorophene', 'triparanol'),
#  ('hexachlorophene', 'ivacaftor'),
#  ('hexachlorophene', 'loperamide'),
#  ('hexachlorophene', 'lopinavir'),
#  ('hexachlorophene', 'mefloquine'),
#  ('hexachlorophene', 'niclosamide'),
#  ('hexachlorophene', 'osimertinib'),
#  ('hexachlorophene', 'proscillaridin'),
#  ('hexachlorophene', 'remdesivir'),
#  ('hexachlorophene', 'tetrandrine'),
#  ('hexachlorophene', 'triparanol'),
#  ('ivacaftor', 'loperamide'),
#  ('ivacaftor', 'lopinavir'),
#  ('ivacaftor', 'mefloquine'),
#  ('ivacaftor', 'niclosamide'),
#  ('ivacaftor', 'osimertinib'),
#  ('ivacaftor', 'proscillaridin'),
#  ('ivacaftor', 'remdesivir'),
#  ('ivacaftor', 'tetrandrine'),
#  ('ivacaftor', 'triparanol'),
#  ('loperamide', 'lopinavir'),
#  ('loperamide', 'mefloquine'),
#  ('loperamide', 'niclosamide'),
#  ('loperamide', 'osimertinib'),
#  ('loperamide', 'proscillaridin'),
#  ('loperamide', 'remdesivir'),
#  ('loperamide', 'tetrandrine'),
#  ('loperamide', 'triparanol'),
#  ('lopinavir', 'mefloquine'),
#  ('lopinavir', 'niclosamide'),
#  ('lopinavir', 'osimertinib'),
#  ('lopinavir', 'proscillaridin'),
#  ('lopinavir', 'remdesivir'),
#  ('lopinavir', 'tetrandrine'),
#  ('lopinavir', 'triparanol'),
#  ('mefloquine', 'niclosamide'),
#  ('mefloquine', 'osimertinib'),
#  ('mefloquine', 'proscillaridin'),
#  ('mefloquine', 'remdesivir'),
#  ('mefloquine', 'tetrandrine'),
#  ('mefloquine', 'triparanol'),
#  ('niclosamide', 'osimertinib'),
#  ('niclosamide', 'proscillaridin'),
#  ('niclosamide', 'remdesivir'),
#  ('niclosamide', 'tetrandrine'),
#  ('niclosamide', 'triparanol'),
#  ('osimertinib', 'proscillaridin'),
#  ('osimertinib', 'remdesivir'),
#  ('osimertinib', 'tetrandrine'),
#  ('osimertinib', 'triparanol'),
#  ('proscillaridin', 'remdesivir'),
#  ('proscillaridin', 'tetrandrine'),
#  ('proscillaridin', 'triparanol'),
#  ('remdesivir', 'tetrandrine'),
#  ('remdesivir', 'triparanol'),
#  ('tetrandrine', 'triparanol'),
#  ('acetylcholine', 'alprostadil'),
#  ('acetylcholine', 'ambroxol'),
#  ('acetylcholine', 'arbidol'),
#  ('acetylcholine', 'azithromycin'),
#  ('acetylcholine', 'chloroquine'),
#  ('acetylcholine', 'cisatracurium'),
#  ('acetylcholine', 'darunavir'),
#  ('acetylcholine', 'dolutegravir'),
#  ('acetylcholine', 'dopamine'),
#  ('acetylcholine', 'epinephrine'),
#  ('acetylcholine', 'erythromycin'),
#  ('acetylcholine', 'estradiol'),
#  ('acetylcholine', 'glutathione'),
#  ('acetylcholine', 'hydroxychloroquine'),
#  ('acetylcholine', 'ibudilast'),
#  ('acetylcholine', 'ifenprodil'),
#  ('acetylcholine', 'isotretinoin'),
#  ('acetylcholine', 'levofloxacin'),
#  ('acetylcholine', 'naltrexone'),
#  ('acetylcholine', 'omeprazole'),
#  ('acetylcholine', 'remdesivir'),
#  ('acetylcholine', 'tamoxifen'),
#  ('acetylcholine', 'thiamine'),
#  ('acetylcholine', 'vonoprazan'),
#  ('alprostadil', 'ambroxol'),
#  ('alprostadil', 'arbidol'),
#  ('alprostadil', 'azithromycin'),
#  ('alprostadil', 'chloroquine'),
#  ('alprostadil', 'cisatracurium'),
#  ('alprostadil', 'darunavir'),
#  ('alprostadil', 'dolutegravir'),
#  ('alprostadil', 'dopamine'),
#  ('alprostadil', 'epinephrine'),
#  ('alprostadil', 'erythromycin'),
#  ('alprostadil', 'estradiol'),
#  ('alprostadil', 'glutathione'),
#  ('alprostadil', 'hydroxychloroquine'),
#  ('alprostadil', 'ibudilast'),
#  ('alprostadil', 'ifenprodil'),
#  ('alprostadil', 'isotretinoin'),
#  ('alprostadil', 'levofloxacin'),
#  ('alprostadil', 'naltrexone'),
#  ('alprostadil', 'omeprazole'),
#  ('alprostadil', 'remdesivir'),
#  ('alprostadil', 'tamoxifen'),
#  ('alprostadil', 'thiamine'),
#  ('alprostadil', 'vonoprazan'),
#  ('ambroxol', 'arbidol'),
#  ('ambroxol', 'azithromycin'),
#  ('ambroxol', 'chloroquine'),
#  ('ambroxol', 'cisatracurium'),
#  ('ambroxol', 'darunavir'),
#  ('ambroxol', 'dolutegravir'),
#  ('ambroxol', 'dopamine'),
#  ('ambroxol', 'epinephrine'),
#  ('ambroxol', 'erythromycin'),
#  ('ambroxol', 'estradiol'),
#  ('ambroxol', 'glutathione'),
#  ('ambroxol', 'hydroxychloroquine'),
#  ('ambroxol', 'ibudilast'),
#  ('ambroxol', 'ifenprodil'),
#  ('ambroxol', 'isotretinoin'),
#  ('ambroxol', 'levofloxacin'),
#  ('ambroxol', 'naltrexone'),
#  ('ambroxol', 'omeprazole'),
#  ('ambroxol', 'remdesivir'),
#  ('ambroxol', 'tamoxifen'),
#  ('ambroxol', 'thiamine'),
#  ('ambroxol', 'vonoprazan'),
#  ('arbidol', 'azithromycin'),
#  ('arbidol', 'chloroquine'),
#  ('arbidol', 'cisatracurium'),
#  ('arbidol', 'darunavir'),
#  ('arbidol', 'dolutegravir'),
#  ('arbidol', 'dopamine'),
#  ('arbidol', 'epinephrine'),
#  ('arbidol', 'erythromycin'),
#  ('arbidol', 'estradiol'),
#  ('arbidol', 'glutathione'),
#  ('arbidol', 'hydroxychloroquine'),
#  ('arbidol', 'ibudilast'),
#  ('arbidol', 'ifenprodil'),
#  ('arbidol', 'isotretinoin'),
#  ('arbidol', 'levofloxacin'),
#  ('arbidol', 'naltrexone'),
#  ('arbidol', 'omeprazole'),
#  ('arbidol', 'remdesivir'),
#  ('arbidol', 'tamoxifen'),
#  ('arbidol', 'thiamine'),
#  ('arbidol', 'vonoprazan'),
#  ('azithromycin', 'chloroquine'),
#  ('azithromycin', 'cisatracurium'),
#  ('azithromycin', 'darunavir'),
#  ('azithromycin', 'dolutegravir'),
#  ('azithromycin', 'dopamine'),
#  ('azithromycin', 'epinephrine'),
#  ('azithromycin', 'erythromycin'),
#  ('azithromycin', 'estradiol'),
#  ('azithromycin', 'glutathione'),
#  ('azithromycin', 'hydroxychloroquine'),
#  ('azithromycin', 'ibudilast'),
#  ('azithromycin', 'ifenprodil'),
#  ('azithromycin', 'isotretinoin'),
#  ('azithromycin', 'levofloxacin'),
#  ('azithromycin', 'naltrexone'),
#  ('azithromycin', 'omeprazole'),
#  ('azithromycin', 'remdesivir'),
#  ('azithromycin', 'tamoxifen'),
#  ('azithromycin', 'thiamine'),
#  ('azithromycin', 'vonoprazan'),
#  ('chloroquine', 'cisatracurium'),
#  ('chloroquine', 'darunavir'),
#  ('chloroquine', 'dolutegravir'),
#  ('chloroquine', 'dopamine'),
#  ('chloroquine', 'epinephrine'),
#  ('chloroquine', 'erythromycin'),
#  ('chloroquine', 'estradiol'),
#  ('chloroquine', 'glutathione'),
#  ('chloroquine', 'hydroxychloroquine'),
#  ('chloroquine', 'ibudilast'),
#  ('chloroquine', 'ifenprodil'),
#  ('chloroquine', 'isotretinoin'),
#  ('chloroquine', 'levofloxacin'),
#  ('chloroquine', 'naltrexone'),
#  ('chloroquine', 'omeprazole'),
#  ('chloroquine', 'remdesivir'),
#  ('chloroquine', 'tamoxifen'),
#  ('chloroquine', 'thiamine'),
#  ('chloroquine', 'vonoprazan'),
#  ('cisatracurium', 'darunavir'),
#  ('cisatracurium', 'dolutegravir'),
#  ('cisatracurium', 'dopamine'),
#  ('cisatracurium', 'epinephrine'),
#  ('cisatracurium', 'erythromycin'),
#  ('cisatracurium', 'estradiol'),
#  ('cisatracurium', 'glutathione'),
#  ('cisatracurium', 'hydroxychloroquine'),
#  ('cisatracurium', 'ibudilast'),
#  ('cisatracurium', 'ifenprodil'),
#  ('cisatracurium', 'isotretinoin'),
#  ('cisatracurium', 'levofloxacin'),
#  ('cisatracurium', 'naltrexone'),
#  ('cisatracurium', 'omeprazole'),
#  ('cisatracurium', 'remdesivir'),
#  ('cisatracurium', 'tamoxifen'),
#  ('cisatracurium', 'thiamine'),
#  ('cisatracurium', 'vonoprazan'),
#  ('darunavir', 'dolutegravir'),
#  ('darunavir', 'dopamine'),
#  ('darunavir', 'epinephrine'),
#  ('darunavir', 'erythromycin'),
#  ('darunavir', 'estradiol'),
#  ('darunavir', 'glutathione'),
#  ('darunavir', 'hydroxychloroquine'),
#  ('darunavir', 'ibudilast'),
#  ('darunavir', 'ifenprodil'),
#  ('darunavir', 'isotretinoin'),
#  ('darunavir', 'levofloxacin'),
#  ('darunavir', 'naltrexone'),
#  ('darunavir', 'omeprazole'),
#  ('darunavir', 'remdesivir'),
#  ('darunavir', 'tamoxifen'),
#  ('darunavir', 'thiamine'),
#  ('darunavir', 'vonoprazan'),
#  ('dolutegravir', 'dopamine'),
#  ('dolutegravir', 'epinephrine'),
#  ('dolutegravir', 'erythromycin'),
#  ('dolutegravir', 'estradiol'),
#  ('dolutegravir', 'glutathione'),
#  ('dolutegravir', 'hydroxychloroquine'),
#  ('dolutegravir', 'ibudilast'),
#  ('dolutegravir', 'ifenprodil'),
#  ('dolutegravir', 'isotretinoin'),
#  ('dolutegravir', 'levofloxacin'),
#  ('dolutegravir', 'naltrexone'),
#  ('dolutegravir', 'omeprazole'),
#  ('dolutegravir', 'remdesivir'),
#  ('dolutegravir', 'tamoxifen'),
#  ('dolutegravir', 'thiamine'),
#  ('dolutegravir', 'vonoprazan'),
#  ('dopamine', 'epinephrine'),
#  ('dopamine', 'erythromycin'),
#  ('dopamine', 'estradiol'),
#  ('dopamine', 'glutathione'),
#  ('dopamine', 'hydroxychloroquine'),
#  ('dopamine', 'ibudilast'),
#  ('dopamine', 'ifenprodil'),
#  ('dopamine', 'isotretinoin'),
#  ('dopamine', 'levofloxacin'),
#  ('dopamine', 'naltrexone'),
#  ('dopamine', 'omeprazole'),
#  ('dopamine', 'remdesivir'),
#  ('dopamine', 'tamoxifen'),
#  ('dopamine', 'thiamine'),
#  ('dopamine', 'vonoprazan'),
#  ('epinephrine', 'erythromycin'),
#  ('epinephrine', 'estradiol'),
#  ('epinephrine', 'glutathione'),
#  ('epinephrine', 'hydroxychloroquine'),
#  ('epinephrine', 'ibudilast'),
#  ('epinephrine', 'ifenprodil'),
#  ('epinephrine', 'isotretinoin'),
#  ('epinephrine', 'levofloxacin'),
#  ('epinephrine', 'naltrexone'),
#  ('epinephrine', 'omeprazole'),
#  ('epinephrine', 'remdesivir'),
#  ('epinephrine', 'tamoxifen'),
#  ('epinephrine', 'thiamine'),
#  ('epinephrine', 'vonoprazan'),
#  ('erythromycin', 'estradiol'),
#  ('erythromycin', 'glutathione'),
#  ('erythromycin', 'hydroxychloroquine'),
#  ('erythromycin', 'ibudilast'),
#  ...]
